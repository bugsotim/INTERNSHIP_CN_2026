# %% [markdown]
# <a href="https://colab.research.google.com/github/bugsotim/INTERNSHIP_CN_2026/blob/main/shopee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
# List the contents of your Google Drive
# You might need to adjust the path if your data is in a specific subfolder
print(os.listdir('/content/drive/MyDrive'))
# Out:
# Mounted at /content/drive
# ...

# %% [markdown]
# # รวมข้อมูลปี2024 - 2026

# %%
import pandas as pd

# 2024
file_path = '/content/drive/MyDrive/intern CHN/shopee2024/2024-01-01_2024-01-31.xlsx'
file_path1 = '/content/drive/MyDrive/intern CHN/shopee2024/2024-02-01_2024-02-29.xlsx'
file_path2 = '/content/drive/MyDrive/intern CHN/shopee2024/2024-03-01_2024-03-31.xlsx'
# 2025
file_path3 = '/content/drive/MyDrive/intern CHN/shopee2025/2025-01-01_2025-01-31_part_1_of_3.xlsx'
file_path4 = '/content/drive/MyDrive/intern CHN/shopee2025/2025-01-01_2025-01-31_part_2_of_3.xlsx'
file_path5 = '/content/drive/MyDrive/intern CHN/shopee2025/2025-01-01_2025-01-31_part_3_of_3.xlsx'
file_path6 ='/content/drive/MyDrive/intern CHN/shopee2025/2025-02-01_2025-02-28_part_1_of_4.xlsx'
file_path7 = '/content/drive/MyDrive/intern CHN/shopee2025/2025-02-01_2025-02-28_part_2_of_4.xlsx'
file_path8 = '/content/drive/MyDrive/intern CHN/shopee2025/2025-02-01_2025-02-28_part_3_of_4.xlsx'
file_path9 = '/content/drive/MyDrive/intern CHN/shopee2025/2025-02-01_2025-02-28_part_4_of_4.xlsx'
file_path10 = '/content/drive/MyDrive/intern CHN/shopee2025/2025-03-01_2025-03-31_part_1_of_4.xlsx'
file_path11 = '/content/drive/MyDrive/intern CHN/shopee2025/2025-03-01_2025-03-31_part_2_of_4.xlsx'
file_path12 = '/content/drive/MyDrive/intern CHN/shopee2025/2025-03-01_2025-03-31_part_3_of_4.xlsx'
file_path13 = '/content/drive/MyDrive/intern CHN/shopee2025/2025-03-01_2025-03-31_part_4_of_4.xlsx'
# 2026
file_path14 = '/content/drive/MyDrive/intern CHN/shopee2026/2026-01-01_2026-01-31_part_1_of_3.xlsx'
file_path15 = '/content/drive/MyDrive/intern CHN/shopee2026/2026-01-01_2026-01-31_part_2_of_3.xlsx'
file_path16 = '/content/drive/MyDrive/intern CHN/shopee2026/2026-01-01_2026-01-31_part_3_of_3.xlsx'
file_path17 = '/content/drive/MyDrive/intern CHN/shopee2026/2026-02-01_2026-02-28_part_1_of_3.xlsx'
file_path18 = '/content/drive/MyDrive/intern CHN/shopee2026/2026-02-01_2026-02-28_part_2_of_3.xlsx'
file_path19 = '/content/drive/MyDrive/intern CHN/shopee2026/2026-02-01_2026-02-28_part_3_of_3.xlsx'
file_path20 = '/content/drive/MyDrive/intern CHN/shopee2026/2026-03-01_2026-03-31_part_1_of_3.xlsx'
file_path21 = '/content/drive/MyDrive/intern CHN/shopee2026/2026-03-01_2026-03-31_part_2_of_3.xlsx'
file_path22 = '/content/drive/MyDrive/intern CHN/shopee2026/2026-03-01_2026-03-31_part_3_of_3.xlsx'

# %%
df_2024_1 = pd.read_excel(file_path)
df_2024_2 = pd.read_excel(file_path1)
df_2024_3 = pd.read_excel(file_path2)
df_2025_1_13 = pd.read_excel(file_path3)
df_2025_1_23 =  pd.read_excel(file_path4)
df_2025_1_33 =  pd.read_excel(file_path5)
df_2025_2_14 =  pd.read_excel(file_path6)
df_2025_2_24 =  pd.read_excel(file_path7)
df_2025_2_34 =  pd.read_excel(file_path8)
df_2025_2_44 =  pd.read_excel(file_path9)
df_2025_3_14 =  pd.read_excel(file_path10)
df_2025_3_24 =  pd.read_excel(file_path11)
df_2025_3_34 =  pd.read_excel(file_path12)
df_2025_3_44 =  pd.read_excel(file_path13)
df_2026_1_13 =  pd.read_excel(file_path14)
df_2026_1_23 =  pd.read_excel(file_path15)
df_2026_1_33 =  pd.read_excel(file_path16)
df_2026_2_13 =  pd.read_excel(file_path17)
df_2026_2_23 =  pd.read_excel(file_path18)
df_2026_2_33 =  pd.read_excel(file_path19)
df_2026_3_13 =  pd.read_excel(file_path20)
df_2026_3_23 =  pd.read_excel(file_path21)
df_2026_3_33 =  pd.read_excel(file_path22)

# %%
import pandas as pd

# เตรียมรายการสำหรับเก็บ DataFrame ที่ขึ้นต้นด้วย 'df_2024'
dfs_2024_prefix = []

# Dynamically collect DataFrames from the global scope that start with 'df_2024'
# Iterate over a copy of globals().items() to avoid RuntimeError if globals() changes during iteration
for var_name, var_value in list(globals().items()):
    if var_name.startswith('df_2024') and isinstance(var_value, pd.DataFrame):
        dfs_2024_prefix.append(var_value)

# รวม DataFrames ที่ขึ้นต้นด้วย 'df_2024'
if dfs_2024_prefix:
    df_2024 = pd.concat(dfs_2024_prefix, ignore_index=True)
    print(f"df_2024 สร้างแล้วด้วย {df_2024.shape[0]} แถว และ {df_2024.shape[1]} คอลัมน์")
else:
    print("ไม่พบข้อมูลสำหรับ DataFrame ที่ขึ้นต้นด้วย 'df_2024'")
# Out:
# df_2024 สร้างแล้วด้วย 4592 แถว และ 73 คอลัมน์

# %%
df_2024
# Out:
#      หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ Hot Listing  \
# 0       240103UWX9N588       สำเร็จแล้ว           N
# 1       240103UWX9N588       สำเร็จแล้ว           N
# 2       240103THAPRG1G       สำเร็จแล้ว           N
# 3       240103THAPRG1G       สำเร็จแล้ว           N
# 4       240102SRPHXTVH       สำเร็จแล้ว           N
# ...                ...              ...         ...
# 4587    240330EUFCVY3C       สำเร็จแล้ว           N
# 4588    240331GQM43KQM       สำเร็จแล้ว           N
# 4589    240331GRQE6CEU       สำเร็จแล้ว           N
# 4590    240330EQK0908C       สำเร็จแล้ว           N
# 4591    240331G6M6HSFB       สำเร็จแล้ว           N
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN           bam_beebee    2024-01-03 12:44
# 1                             NaN           bam_beebee    2024-01-03 12:44
# 2                             NaN         preorder_usa    2024-01-02 23:26
# ...

# %%
import pandas as pd

# เตรียมรายการสำหรับเก็บ DataFrame ที่ขึ้นต้นด้วย 'df_2024'
dfs_2025_prefix = []

# Dynamically collect DataFrames from the global scope that start with 'df_2024'
# Iterate over a copy of globals().items() to avoid RuntimeError if globals() changes during iteration
for var_name, var_value in list(globals().items()):
    if var_name.startswith('df_2025') and isinstance(var_value, pd.DataFrame):
        dfs_2025_prefix.append(var_value)

# รวม DataFrames ที่ขึ้นต้นด้วย 'df_2024'
if dfs_2025_prefix:
    df_2025 = pd.concat(dfs_2025_prefix, ignore_index=True)
    print(f"df_2024 สร้างแล้วด้วย {df_2025.shape[0]} แถว และ {df_2025.shape[1]} คอลัมน์")
else:
    print("ไม่พบข้อมูลสำหรับ DataFrame ที่ขึ้นต้นด้วย 'df_2025'")
# Out:
# df_2024 สร้างแล้วด้วย 61391 แถว และ 73 คอลัมน์

# %%
df_2025
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ Hot Listing  \
# 0        250102E0B7D4X4       สำเร็จแล้ว           N
# 1        250102EFV9RQUW       สำเร็จแล้ว           N
# 2        250102E8FJSDXV       สำเร็จแล้ว           N
# 3        250102ECJPV9NA       สำเร็จแล้ว           N
# 4        250102ECJPV9NA       สำเร็จแล้ว           N
# ...                 ...              ...         ...
# 61386    2503313BJWES1M       สำเร็จแล้ว           N
# 61387    2503313DPTU102       สำเร็จแล้ว           N
# 61388    2503313NWV1AH4       สำเร็จแล้ว           N
# 61389    2503313T8N9VRG       สำเร็จแล้ว           N
# 61390    2503313T8N9VRG       สำเร็จแล้ว           N
#
#       สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                              NaN           wy2t1sqihe    2025-01-02 08:43
# 1                              NaN        piyathida0604    2025-01-02 13:21
# 2                              NaN      wanichaya180147    2025-01-02 11:09
# ...

# %%
import pandas as pd

# เตรียมรายการสำหรับเก็บ DataFrame ที่ขึ้นต้นด้วย 'df_2024'
dfs_2026_prefix = []

# Dynamically collect DataFrames from the global scope that start with 'df_2024'
# Iterate over a copy of globals().items() to avoid RuntimeError if globals() changes during iteration
for var_name, var_value in list(globals().items()):
    if var_name.startswith('df_2026') and isinstance(var_value, pd.DataFrame):
        dfs_2026_prefix.append(var_value)

# รวม DataFrames ที่ขึ้นต้นด้วย 'df_2024'
if dfs_2026_prefix:
    df_2026 = pd.concat(dfs_2026_prefix, ignore_index=True)
    print(f"df_2026 สร้างแล้วด้วย {df_2026.shape[0]} แถว และ {df_2026.shape[1]} คอลัมน์")
else:
    print("ไม่พบข้อมูลสำหรับ DataFrame ที่ขึ้นต้นด้วย 'df_2026'")
# Out:
# df_2026 สร้างแล้วด้วย 52091 แถว และ 73 คอลัมน์

# %%
df_2026
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ Hot Listing  \
# 0        2601020MK5JEW9       สำเร็จแล้ว           N
# 1        2601020T07MDUW       สำเร็จแล้ว           N
# 2        260101U6S1XGNM       สำเร็จแล้ว           N
# 3        2601020R8DBG19       สำเร็จแล้ว           N
# 4        260102VSK57ES2       สำเร็จแล้ว           N
# ...                 ...              ...         ...
# 52086    260331JHGT5Q6J       สำเร็จแล้ว           N
# 52087    260401KMUCRTYX       สำเร็จแล้ว           N
# 52088    260401KMUCRTYX       สำเร็จแล้ว           N
# 52089    260331JQFA1UTK       สำเร็จแล้ว           N
# 52090    260331KGWSY0SN       สำเร็จแล้ว           N
#
#       สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                              NaN       suwannasrithon    2026-01-02 10:01
# 1                              NaN           chalichi29    2026-01-02 11:38
# 2                              NaN           ihd5qo0pn9    2026-01-01 09:49
# ...

# %%
import pandas as pd

# รวม DataFrames df_2024, df_2025, และ df_2026 เข้าด้วยกัน
# ตรวจสอบว่า DataFrames มีอยู่ก่อนที่จะทำการรวม

all_dfs_to_concat = []

if 'df_2024' in locals() and not df_2024.empty:
    all_dfs_to_concat.append(df_2024)
    print(f"df_2024 มี {df_2024.shape[0]} แถว")
else:
    print("ไม่พบ df_2024 หรือเป็น DataFrame ว่าง")

if 'df_2025' in locals() and not df_2025.empty:
    all_dfs_to_concat.append(df_2025)
    print(f"df_2025 มี {df_2025.shape[0]} แถว")
else:
    print("ไม่พบ df_2025 หรือเป็น DataFrame ว่าง")

if 'df_2026' in locals() and not df_2026.empty:
    all_dfs_to_concat.append(df_2026)
    print(f"df_2026 มี {df_2026.shape[0]} แถว")
else:
    print("ไม่พบ df_2026 หรือเป็น DataFrame ว่าง")

if all_dfs_to_concat:
    shopee = pd.concat(all_dfs_to_concat, ignore_index=True)
    print(f"\nDataFrame 'shopee' สร้างแล้วด้วย {shopee.shape[0]} แถว และ {shopee.shape[1]} คอลัมน์")
else:
    print("ไม่พบ DataFrame ที่จะนำมารวมกัน ไม่มี DataFrame 'shopee' ถูกสร้างขึ้น")
# Out:
# df_2024 มี 4592 แถว
# df_2025 มี 61391 แถว
# df_2026 มี 52091 แถว
#
# DataFrame 'shopee' สร้างแล้วด้วย 118074 แถว และ 73 คอลัมน์

# %%
shopee
# Out:
#        หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ Hot Listing  \
# 0         240103UWX9N588       สำเร็จแล้ว           N
# 1         240103UWX9N588       สำเร็จแล้ว           N
# 2         240103THAPRG1G       สำเร็จแล้ว           N
# 3         240103THAPRG1G       สำเร็จแล้ว           N
# 4         240102SRPHXTVH       สำเร็จแล้ว           N
# ...                  ...              ...         ...
# 118069    260331JHGT5Q6J       สำเร็จแล้ว           N
# 118070    260401KMUCRTYX       สำเร็จแล้ว           N
# 118071    260401KMUCRTYX       สำเร็จแล้ว           N
# 118072    260331JQFA1UTK       สำเร็จแล้ว           N
# 118073    260331KGWSY0SN       สำเร็จแล้ว           N
#
#        สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                               NaN           bam_beebee    2024-01-03 12:44
# 1                               NaN           bam_beebee    2024-01-03 12:44
# 2                               NaN         preorder_usa    2024-01-02 23:26
# ...

# %%
output_path = '/content/drive/MyDrive/intern CHN/shopee_combined_data.xlsx'
shopee.to_excel(output_path, index=False)
print(f"DataFrame 'shopee' ถูกส่งออกไปยัง '{output_path}' เรียบร้อยแล้ว")
# Out:
# DataFrame 'shopee' ถูกส่งออกไปยัง '/content/drive/MyDrive/intern CHN/shopee_combined_data.xlsx' เรียบร้อยแล้ว

# %% [markdown]
# # ไฟล์รวมปี

# %%
file_path_01 = '/content/drive/MyDrive/intern CHN/shopee_combined_data.xlsx'

# %%
shopee1=  pd.read_excel(file_path_01)

# %%
shopee1.shape
# Out:
# (118074, 73)

# %%
shopee1
# Out:
#        หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ Hot Listing  \
# 0         240103UWX9N588       สำเร็จแล้ว           N
# 1         240103UWX9N588       สำเร็จแล้ว           N
# 2         240103THAPRG1G       สำเร็จแล้ว           N
# 3         240103THAPRG1G       สำเร็จแล้ว           N
# 4         240102SRPHXTVH       สำเร็จแล้ว           N
# ...                  ...              ...         ...
# 118069    260331JHGT5Q6J       สำเร็จแล้ว           N
# 118070    260401KMUCRTYX       สำเร็จแล้ว           N
# 118071    260401KMUCRTYX       สำเร็จแล้ว           N
# 118072    260331JQFA1UTK       สำเร็จแล้ว           N
# 118073    260331KGWSY0SN       สำเร็จแล้ว           N
#
#        สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                               NaN           bam_beebee    2024-01-03 12:44
# 1                               NaN           bam_beebee    2024-01-03 12:44
# 2                               NaN         preorder_usa    2024-01-02 23:26
# ...

# %% [markdown]
# ## ลบคอลัมน์ที่ไม่ใช้

# %%
columns_to_drop = [
    'สถานะการสั่งซื้อ',
    'Hot Listing',
    'ชื่อผู้ใช้ (ผู้ซื้อ)',
    'วิธีการจัดส่ง',
    'หมายเลขติดตามพัสดุ',
    'เลขอ้างอิง Parent SKU',
    'โค้ด Coins Cashback ชำระโดยผู้ขาย',
    'โค้ดส่วนลด',
    'เข้าร่วมแคมเปญ bundle deal หรือไม่',
    'ส่วนลด bundle deal ชำระโดยผู้ขาย',
    'ส่วนลด bundle deal ชำระโดย Shopee',
    'โปรโมชั่นช่องทางชำระเงินทั้งหมด',
    'ส่วนลดเครื่องเก่าแลกใหม่',
    'โบนัสส่วนลดเครื่องเก่าแลกใหม่',
    'Transaction Fee',
    'ค่าจัดส่งที่ชำระโดยผู้ซื้อ',
    'ค่าจัดส่งที่ Shopee ออกให้โดยประมาณ',
    'ค่าจัดส่งสินค้าคืน',
    'โบนัสส่วนลดเครื่องเก่าแลกใหม่จากผู้ขาย',
    'ชื่อผู้รับ',
    'หมายเลขโทรศัพท์',
    'หมายเหตุจากผู้ซื้อ',
    'ที่อยู่ในการจัดส่ง',
    'รหัสไปรษณีย์',
    'ประเภทคำสั่งซื้อ',
    'บันทึก',
    'ผู้ซื้อร้องขอใบกำกับภาษี',
    'ประเภทใบกำกับภาษี',
    'ชื่อ',
    'ประเภทสาขา',
    'ชื่อสาขา',
    'รหัสประจำสาขา',
    'ที่อยู่สำหรับออกใบกำกับภาษีแบบเต็มรูป',
    'รายละเอียดที่อยู่',
    'แขวง/ตำบล',
    'เขต/อำเภอ.1',
    'จังหวัด.1',
    'รหัสไปรษณีย์.1',
    'หมายเลขประจำตัวผู้เสียภาษี',
    'หมายเลขโทรศัพท์สำหรับออกใบกำกับภาษี',
    'อีเมลสำหรับรับใบกำกับภาษี'
]

# Drop the specified columns
shopee1 = shopee1.drop(columns=columns_to_drop, errors='ignore')

print(f"DataFrame 'shopee1' หลังจากลบคอลัมน์: {shopee1.shape[0]} แถว และ {shopee1.shape[1]} คอลัมน์")
# Out:
# DataFrame 'shopee1' หลังจากลบคอลัมน์: 118074 แถว และ 33 คอลัมน์

# %%
shopee1
# Out:
#        หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0         240103UWX9N588                          NaN    2024-01-03 12:44
# 1         240103UWX9N588                          NaN    2024-01-03 12:44
# 2         240103THAPRG1G                          NaN    2024-01-02 23:26
# 3         240103THAPRG1G                          NaN    2024-01-02 23:26
# 4         240102SRPHXTVH                          NaN    2024-01-02 16:05
# ...                  ...                          ...                 ...
# 118069    260331JHGT5Q6J                          NaN    2026-03-31 13:21
# 118070    260401KMUCRTYX                          NaN    2026-03-31 23:53
# 118071    260401KMUCRTYX                          NaN    2026-03-31 23:53
# 118072    260331JQFA1UTK                          NaN    2026-03-31 15:08
# 118073    260331KGWSY0SN                          NaN    2026-03-31 22:43
#
#        เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
import re

# Define the keywords to search for
keywords_to_search = [
    '[ของแถม]',
    '[สินค้าแถม ห้ามกดสั่งซื้อ]'
]

# Escape special characters in each keyword for regex and join them with '|'
escaped_keywords_for_filter = [re.escape(k) for k in keywords_to_search]
pattern_for_filter = '|'.join(escaped_keywords_for_filter)

# Filter the DataFrame
filtered_items = shopee1[shopee1['ชื่อสินค้า'].str.contains(pattern_for_filter, na=False, regex=True)]

print(f"จำนวนรายการที่พบ: {len(filtered_items)}")
# Display the filtered DataFrame
filtered_items
# Out:
# จำนวนรายการที่พบ: 22594
#        หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 4596      250102ECJPV9NA                          NaN    2025-01-02 12:22
# 4598      250102DN5YQ4K6                          NaN    2025-01-02 05:23
# 4600      250102E7XUR6BB                          NaN    2025-01-02 10:59
# 4608      250102EA99YKEK                          NaN    2025-01-02 11:41
# 4611      250102EF36RFFV                          NaN    2025-01-02 13:07
# ...                  ...                          ...                 ...
# 118011    260331K82J94MU                          NaN    2026-03-31 20:05
# 118041    260330FXRY3KB9                          NaN    2026-03-30 12:40
# 118052    2603253JUD1FET                          NaN    2026-03-25 14:35
# 118056    260331KE8U3JD8                          NaN    2026-03-31 21:56
# 118066    260331K3Y3MHG4                          NaN    2026-03-31 18:51
#
# ...

# %%
import re

# Define the keywords to remove
keywords_to_remove = [
    '[ของแถม]',
    '[สินค้าแถม ห้ามกดสั่งซื้อ]'
]

# Escape special characters in each keyword for regex and join them with '|'
escaped_keywords_for_removal = [re.escape(k) for k in keywords_to_remove]
pattern_for_removal = '|'.join(escaped_keywords_for_removal);

# Create a boolean mask for rows that contain any of the keywords
# The '~' operator negates the mask, selecting rows that do NOT contain the keywords
shopee1 = shopee1[~shopee1['ชื่อสินค้า'].str.contains(pattern_for_removal, na=False, regex=True)];

print(f"DataFrame 'shopee1' หลังจากลบแถว: {shopee1.shape[0]} แถว และ {shopee1.shape[1]} คอลัมน์")
# Out:
# DataFrame 'shopee1' หลังจากลบแถว: 95480 แถว และ 33 คอลัมน์

# %%
shopee1.shape
# Out:
# (95480, 33)

# %% [markdown]
# ## สร้างคอลัมน์ SKU เก่า,ใหม่

# %%
shopee1['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee1['วันที่ทำการสั่งซื้อ'])

# Initialize 'SKU' column as object type to hold strings and NaNs without warning
shopee1['SKU'] = None # or pd.NA, or '' for empty string, None works well with object dtype

# Set SKU to 'เก่า' for rows from 2024
shopee1.loc[shopee1['วันที่ทำการสั่งซื้อ'].dt.year == 2024, 'SKU'] = 'เก่า'

print(shopee1[['วันที่ทำการสั่งซื้อ', 'SKU']].head()) # Display head to verify changes
print(shopee1[['วันที่ทำการสั่งซื้อ', 'SKU']].tail()) # Display tail to verify changes
print(shopee1['SKU'].value_counts(dropna=False)) # Check distribution of SKU values
# Out:
#   วันที่ทำการสั่งซื้อ   SKU
# 0 2024-01-03 12:44:00  เก่า
# 1 2024-01-03 12:44:00  เก่า
# 2 2024-01-02 23:26:00  เก่า
# 3 2024-01-02 23:26:00  เก่า
# 4 2024-01-02 16:05:00  เก่า
#        วันที่ทำการสั่งซื้อ   SKU
# 118069 2026-03-31 13:21:00  None
# 118070 2026-03-31 23:53:00  None
# 118071 2026-03-31 23:53:00  None
# 118072 2026-03-31 15:08:00  None
# 118073 2026-03-31 22:43:00  None
# SKU
# None    90888
# เก่า     4592
# Name: count, dtype: int64
# /tmp/ipykernel_2224/3472209613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shopee1['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee1['วันที่ทำการสั่งซื้อ'])
# /tmp/ipykernel_2224/3472209613.py:4: SettingWithCopyWarning:
# ...

# %%
shopee1
# Out:
#        หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0         240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1         240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2         240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3         240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4         240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                  ...                          ...                 ...
# 118069    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 118070    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 118071    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 118072    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 118073    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#        เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
new_sku_products = [
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง (12 กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (12 box)',
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง (24 กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (24 box)',
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง (48 กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (48 box)',
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง (6กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (6 box)',
    '[1แถม1] ดินสอเขียนคิ้วเจ้านาง (แบบซอง) - Chaonang Slim Waterproof Eyebrow',
    '[Chaonang set] แป้งพัฟเจ้านาง + พัฟฟองน้ำซอง',
    '[Chaonang set] แป้งพัฟเจ้านาง + รองพื้นซองยกกล่อง',
    '[Double Day 1-7 ก.พ.] คุชชั่น + รองพื้นหลอด',
    '[Double Day 1-7 ก.พ.] รองพื้นหลอด + ดินสอเขียนคิ้ว(แบบกล่อง)',
    '[Double Day 2-8 มี.ค.] คุชชั่น + อายไลเนอร์(แบบกล่อง)',
    '[Double Day 2-8 มี.ค.] แป้งพัฟ + รองพื้นซองสูตรเดิม + ดินสอเขียนคิ้ว(แบบกล่อง)',
    '[Double Day 2-8 มี.ค.] แป้งพัฟเจ้านาง + รองพื้น glass skin 2 ซอง',
    '[Flash Sale] ดินสอเขียนคิ้วเจ้านาง(กล่อง) - Chaonang Slim Waterproof Eyebrow EXP 11/8/2025',
    '[Mid Month 11-17 มี.ค.] แป้งฝุ่นเจ้านาง + รองพื้นซองสูตรเดิมยกกล่อง1 กล่อง',
    '[Mid Month 11-17 มี.ค.] แป้งพัฟเจ้านาง + รองพื้น glass skin 1 กล่อง',
    '[Mid Month 11-17ก.พ.] คุชชั่น + ดินสอเขียนคิ้ว(แบบกล่อง)',
    '[Mid Month 11-17ก.พ.] ดินสอเขียนคิ้ว(แบบกล่อง) + อายไลเนอร์(แบบกล่อง)',
    '[Pay Day 25-31 มี.ค.] ลิปบาล์มเจ้านาง + แป้งพัฟเจ้านาง',
    '[เซตผิวสวยท้าแดด] คุชชั่นเจ้านาง (15ก.)  + กันแดดเจ้านาง (30ก.)',
    '[เซตผิวสวยท้าแดด] แป้งพัฟเจ้านาง (10ก.) + กันแดดเจ้านาง (30ก.)',
    '[เซตผิวสวยท้าแดด] รองพื้นเจ้านาง (15ก.) + กันแดดเจ้านาง (30ก.)',
    '[เซทบำรุงผิว] ลิปบาล์ม + กันแดดเจ้านาง',
    '[แพ็ค 2 ชิ้น สุดคุ้ม] กันแดดเจ้านาง (30ก.) - Chaonang Milky Sunscreen SPF50+ PA+++ 30g.',
    '[แพ็ค 2 ชิ้น สุดคุ้ม] แป้งฝุ่นเจ้านาง (6.5ก.) - Chaonang Diamond Translucent Powder 6.5g.',
    '[แพ็ค 2 ตลับ สุดคุ้ม] คุชชั่นเจ้านาง (15ก.) - Chaonang Glowy Cushion SPF30 PA+++ 15g.',
    '[แพ็ค 2 ตลับ สุดคุ้ม] แป้งพัฟเจ้านาง (10ก.) - Chaonang Perfect Bright UV 2-way Powder Foundation 10g.',
    '[แพ็ค 2 หลอด สุดคุ้ม] รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 5g.',
    '[แพ็ค 3 ชิ้น คุ้มสุดๆ] แป้งฝุ่นเจ้านาง (6.5ก.) - Chaonang Diamond Translucent Powder 6.5g.',
    '[แพ็ค 3 ตลับ คุ้มสุดๆ] แป้งพัฟเจ้านาง (10ก.) - Chaonang Perfect Bright UV 2-way Powder Foundation 10g.',
    '[แพ็ค 3 หลอด สุดคุ้ม] รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 15g.',
    '[แพ็คสุดคุ้ม 2 Box ] รองพื้นซอง(6pcs/Box)-Chaonang Radiance Skin Foundation SPF30 PA+++',
    '[แพ็คสุดคุ้ม 3 ตลับ] คุชชั่นเจ้านาง - Chaonang glowy cushion spf30 pa+++',
    '[ใหม่] แป้งฝุ่นเจ้านาง + รองพื้น glass skin 1 กล่อง',
    '[ใหม่] แป้งฝุ่นเจ้านาง + รองพื้น glass skin 2 ซอง',
    '[ใหม่] แป้งพัฟเจ้านาง + รองพื้น glass skin 2 ซอง',
    '[ใหม่] ลิปบาล์มเจ้านาง + คุชชั่นเจ้านาง',
    '[ใหม่] ลิปบาล์มเจ้านาง + แป้งฝุ่นเจ้านาง',
    '[ใหม่] ลิปบาล์มเจ้านาง + แป้งพัฟเจ้านาง',
    '[ใหม่] ลิปบาล์มเจ้านาง + รองพื้นหลอดเจ้านาง',
    'ลิปบาล์มเจ้านาง - Chaonang Glowy Tint Balm SPF15 PA+++',
    'กันแดดเจ้านาง (30ก.) - Chaonang Milky Sunscreen SPF50+ PA+++ 30g.',
    'รองพื้นเจ้านางผิวกระจก แบบซอง (5ก.) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g.',
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง (6ซอง/กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (6pcs/box)'
]

# Get the mask for 2025 entries
is_2025 = (shopee1['วันที่ทำการสั่งซื้อ'].dt.year == 2025)

# Apply 'ใหม่' for specified products in 2025
shopee1.loc[is_2025 & (shopee1['ชื่อสินค้า'].isin(new_sku_products)), 'SKU'] = 'newst'

# Apply 'เก่า' for other products in 2025
shopee1.loc[is_2025 & (~shopee1['ชื่อสินค้า'].isin(new_sku_products)), 'SKU'] = 'oldset'

print(shopee1[shopee1['วันที่ทำการสั่งซื้อ'].dt.year == 2025][['วันที่ทำการสั่งซื้อ', 'ชื่อสินค้า', 'SKU']].head())
print(shopee1[shopee1['วันที่ทำการสั่งซื้อ'].dt.year == 2025][['วันที่ทำการสั่งซื้อ', 'ชื่อสินค้า', 'SKU']].tail())
print(shopee1['SKU'].value_counts(dropna=False))
# Out:
#      วันที่ทำการสั่งซื้อ                                         ชื่อสินค้า  \
# 4592 2025-01-02 08:43:00  รองพื้นเจ้านาง แบบซอง (5ก.) - Chaonang Radianc...
# 4593 2025-01-02 13:21:00  รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin...
# 4594 2025-01-02 11:09:00  รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin...
# 4595 2025-01-02 12:22:00  [แพ็คสุดคุ้ม 2 Box ] รองพื้นซอง(6pcs/Box)-Chao...
# 4597 2025-01-02 05:23:00  [แพ็ค 2 หลอด สุดคุ้ม] รองพื้นเจ้านาง (15ก.) - ...
#
#          SKU
# 4592  oldset
# 4593  oldset
# 4594  oldset
# 4595   newst
# 4597  oldset
#       วันที่ทำการสั่งซื้อ                                         ชื่อสินค้า  \
# 65978 2025-03-31 17:18:00  (สูตรใหม่) รองพื้นเจ้านางผิวกระจก แบบซอง (5ก.)...
# 65979 2025-03-31 17:56:00  รองพื้นเจ้านาง แบบซอง (5ก.) - Chaonang Radianc...
# 65980 2025-03-31 20:23:00  รองพื้นเจ้านาง แบบซอง (5ก.) - Chaonang Radianc...
# 65981 2025-03-31 21:41:00  (สูตรใหม่) รองพื้นเจ้านางผิวกระจก แบบซอง (5ก.)...
# ...

# %%
shopee1[shopee1['วันที่ทำการสั่งซื้อ'].dt.year == 2025]
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 4592     250102E0B7D4X4                          NaN 2025-01-02 08:43:00
# 4593     250102EFV9RQUW                          NaN 2025-01-02 13:21:00
# 4594     250102E8FJSDXV                          NaN 2025-01-02 11:09:00
# 4595     250102ECJPV9NA                          NaN 2025-01-02 12:22:00
# 4597     250102DN5YQ4K6                          NaN 2025-01-02 05:23:00
# ...                 ...                          ...                 ...
# 65978    2503313BJWES1M                          NaN 2025-03-31 17:18:00
# 65979    2503313DPTU102                          NaN 2025-03-31 17:56:00
# 65980    2503313NWV1AH4                          NaN 2025-03-31 20:23:00
# 65981    2503313T8N9VRG                          NaN 2025-03-31 21:41:00
# 65982    2503313T8N9VRG                          NaN 2025-03-31 21:41:00
#
#       เวลาการชำระสินค้า ช่องทางการชำระเงิน ช่องทางการชำระเงิน (รายละเอียด)  \
# ...

# %%
new_sku_products_2026 = [
    'Airy คุชชั่นเจ้านางแบบกล่อง (1กล่อง) - Chaonang Airy Cushion SPF35 PA+++ (1BOX)',
    'Care Skin รองพื้นเจ้านางแคร์สกิน (1กล่อง) - Chaonang Care Skin Foundation SPF30 PA+++ (1BOX)',
    'Glass skin รองพื้นเจ้านางผิวกระจกแบบกล่อง (6กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (6 box)',
    'Glass skin รองพื้นเจ้านางผิวกระจกแบบกล่อง(1กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g.(1 Box)',
    'Glowy Tint รองพื้นเจ้านางโกลว์วี่ทินท์ (1กล่อง) - Chaonang Glowy Tint Foundation SPF30 PA+++ 5g. (1BOX)',
    '[1 แถม 1] บลัชออนเจ้านาง เจ้านาง ซอฟต์บลัช พาวเดอร์ - Chaonang Soft Blush Powder',
    '[1แถม1] ลิปเจ้านาง Glowy Bloom - Chaonang Glowy Bloom Liquid Lip 2.5g.',
    '[แพ็ค 2 ตลับ สุดคุ้ม] แป้งพัฟเจ้านาง To go ขนาด 5g. - Chaonang Perfect Bright UV 2 Way Powder Foundation To go',
    '[แพ็ค 2 ตลับ] แป้งฝุ่นเจ้านาง Glow Filter - Chaonang Glow Filter Translucent Powder 6.5g.',
    '[แพ็ค 2 ตลับ] แป้งพัฟเจ้านาง Glow Skin  - Chaonang Glow Skin Foundation 10g.',
    '[แพ็ค 3 ตลับ สุดคุ้ม] แป้งพัฟเจ้านาง To go ขนาด 5g. - Chaonang Perfect Bright UV 2 Way Powder Foundation To go',
    '[แพ็ค 3 ตลับ] แป้งฝุ่นเจ้านาง Glow Filter - Chaonang Glow Filter Translucent Powder 6.5g.',
    '[แพ็ค 3 ตลับ] แป้งพัฟเจ้านาง Glow Skin - Chaonang Glow Skin Powder Foundation 10g.',
    '[แพ็ค 6 ตลับ] แป้งพัฟเจ้านาง Glow Skin - Chaonang Glow Skin Powder Foundation 10g.',
    '[แพ็คสุดคุ้ม 2 Box ] Care skin รองพื้นเจ้านางแคร์สกิน - Chaonang Care Skin Foundation SPF30 PA+++',
    '[แพ็คสุดคุ้ม 2 Box ] Glowy Tint รองพื้นเจ้านางโกลว์วี่ทินท์ - Chaonang Glowy Tint Foundation SPF30 PA+++',
    '[แพ็คสุดคุ้ม 2 Box] Airy คุชชั่นเจ้านางแบบซอง - Chaonang Airy Cushion SPF35 PA+++',
    '[แพ็คสุดคุ้ม 2 Box] Glass skin รองพื้นเจ้านางผิวกระจกแบบกล่อง - Chaonang Glass Skin Foundation SPF30 PA+++',
    '[แพ็คสุดคุ้ม 3 Box ] Care skin รองพื้นเจ้านางแคร์สกิน - Chaonang Care Skin Foundation SPF30 PA+++',
    '[หมดอายุ 12/2026] คุชชั่นเจ้านาง + Airy คุชชั่นเจ้านาง 1 ซอง',
    'Airy คุชชั่นซองเจ้านาง 3 ซอง + คอนซีลเลอร์เจ้านาง 1 ซอง',
    'คอนซีลเลอร์เจ้านาง + แป้งพัฟเจ้านาง',
    'คอนซีลเลอร์เจ้านาง + แป้งพัฟเจ้านาง Glow skin',
    'คอนซีลเลอร์เจ้านาง + รองพื้นหลอดเจ้านาง',
    'แป้งฝุ่นเจ้านาง Glow filter +  Airy คุชชั่นซองเจ้านาง 2 ซอง',
    'แป้งฝุ่นเจ้านาง Glow Filter + แป้งพัฟเจ้านาง',
    'แป้งฝุ่นเจ้านาง Glow filter + รองพื้นซองเจ้านางสูตร Glass skin 2 ซอง',
    'แป้งฝุ่นเจ้านาง Glow filter + รองพื้นซองเจ้านางสูตร Radiance 2 ซอง',
    'แป้งฝุ่นเจ้านาง Glow Filter + รองพื้นหลอดเจ้านาง',
    'แป้งพัฟเจ้านาง (10g.) + แป้งพัฟเจ้านาง To go (5g.)',
    'แป้งพัฟเจ้านาง +  Airy คุชชั่นซองเจ้านาง 2 ซอง',
    'แป้งพัฟเจ้านาง + Airy คุชชั่นซองเจ้านาง 1 box',
    'แป้งพัฟเจ้านาง + รองพื้นเจ้านางสูตร glass skin 2 ซอง',
    'แป้งพัฟเจ้านาง Glow skin + คุชชั่นเจ้านาง [คุชชั่นหมดอายุ 12/2026]',
    'แป้งพัฟเจ้านาง Glow skin + แป้งฝุ่นเจ้านาง Glow Filter',
    'แป้งพัฟเจ้านาง Glow skin + แป้งพัฟเจ้านาง To go',
    'แป้งพัฟเจ้านาง Glow skin + รองพื้นหลอดเจ้านาง',
    'แป้งพัฟเจ้านาง To go + Airy คุชชั่นซองเจ้านาง 1 ซอง',
    'แป้งพัฟเจ้านาง To go + รองพื้นซองเจ้านาง สูตร Care Skin 1 ซอง',
    'แป้งพัฟเจ้านาง To go + รองพื้นซองเจ้านาง สูตร Glass Skin 1 ซอง',
    'แป้งพัฟเจ้านาง To go + รองพื้นซองเจ้านาง สูตร Glowy Tint 1 ซอง',
    'แป้งพัฟเจ้านาง To go + รองพื้นซองเจ้านาง สูตร Radiance 1 ซอง',
    'รองพื้นเจ้านางสูตร Glass skin 3 ซอง + คอนซีลเลอร์เจ้านาง 1 ซอง',
    'รองพื้นซองเจ้านาง Care skin 2 ซอง + แป้งพัฟเจ้านาง To go',
    'รองพื้นซองเจ้านาง Care skin 3 ซอง + แป้งพัฟเจ้านาง Glow Skin',
    'ลิปเจ้านาง Glowy Bloom + บลัชออนเจ้านาง Soft Blush Powder',
    'แป้งพัฟเจ้านาง+รองพื้นซองเจ้านางสูตร glass skin ยกกล่อง'
]

# Get the mask for 2026 entries
is_2026 = (shopee1['วันที่ทำการสั่งซื้อ'].dt.year == 2026)

# Apply 'ใหม่' for specified products in 2026
shopee1.loc[is_2026 & (shopee1['ชื่อสินค้า'].isin(new_sku_products_2026)), 'SKU'] = 'newset'

# Apply 'เก่า' for other products in 2026
shopee1.loc[is_2026 & (~shopee1['ชื่อสินค้า'].isin(new_sku_products_2026)), 'SKU'] = 'oldset'

print(shopee1[shopee1['วันที่ทำการสั่งซื้อ'].dt.year == 2026][['วันที่ทำการสั่งซื้อ', 'ชื่อสินค้า', 'SKU']].head())
print(shopee1[shopee1['วันที่ทำการสั่งซื้อ'].dt.year == 2026][['วันที่ทำการสั่งซื้อ', 'ชื่อสินค้า', 'SKU']].tail())
print(shopee1['SKU'].value_counts(dropna=False))
# Out:
#       วันที่ทำการสั่งซื้อ                                         ชื่อสินค้า  \
# 65983 2026-01-02 10:01:00  แป้งพัฟเจ้านาง To go ขนาด 5g. - Chaonang Perfe...
# 65984 2026-01-02 11:38:00  แป้งพัฟเจ้านาง Glow Skin - Chaonang Glow Skin ...
# 65985 2026-01-01 09:49:00  รองพื้นเจ้านาง แบบซอง (5ก.) - Chaonang Radianc...
# 65986 2026-01-02 11:07:00  Glass skin รองพื้นเจ้านางผิวกระจกแบบกล่อง(1กล่...
# 65987 2026-01-02 00:59:00  แป้งพัฟเจ้านาง To go ขนาด 5g. - Chaonang Perfe...
#
#           SKU
# 65983  oldset
# 65984  oldset
# 65985  oldset
# 65986  newset
# 65987  oldset
#        วันที่ทำการสั่งซื้อ                                         ชื่อสินค้า  \
# 118069 2026-03-31 13:21:00  แป้งพัฟเจ้านาง To go ขนาด 5g. - Chaonang Perfe...
# 118070 2026-03-31 23:53:00  Glowy Tint รองพื้นเจ้านางโกลว์วี่ทินท์ (5ก.) -...
# 118071 2026-03-31 23:53:00  Glowy Tint รองพื้นเจ้านางโกลว์วี่ทินท์ (5ก.) -...
# 118072 2026-03-31 15:08:00  แป้งเจ้านาง 10ก. (แพคเกจใหม่) - Chaonang Perfe...
# ...

# %% [markdown]
# ## Macadamia
# 1. Double Day
# 2. Flash Sale
# 3. Mid Month
# 4. Pay Day
# 5. Hello 2025

# %%
import re

keywords = [
'[Double Day 1-7 ก.พ.]' ,
'[Double Day 2-8 มี.ค.]',
'[Flash Sale]',
'[Mid Month 11-17 มี.ค.]',
'[Pay Day 25-31 มี.ค.]',
'[Hello 2025 | 4-10 ม.ค.]',
'[Pay Day 20-28 ก.พ.] ',
'[Pay Day 25-30 เม.ย.]',
'[Hello 2025]',
'[PayDay ]',
'[Mid Month]',
'[Set 3.3] ',
'(MID MONTH SET A)',
'[Mid Month SET B]',
]

# Escape special regex characters in each keyword
escaped_keywords = [re.escape(k) for k in keywords]

# Create a regex pattern to search for any of the escaped keywords
pattern = '|'.join(escaped_keywords)

# Filter rows where 'ชื่อสินค้า' contains any of the keywords
matching_rows = shopee1[shopee1['ชื่อสินค้า'].str.contains(pattern, na=False, regex=True)]

print(f"จำนวนแถวทั้งหมดที่มีคำเหล่านี้ในคอลัมน์ 'ชื่อสินค้า': {len(matching_rows)} แถว")

# Display the matching rows
matching_rows
# Out:
# จำนวนแถวทั้งหมดที่มีคำเหล่านี้ในคอลัมน์ 'ชื่อสินค้า': 1657 แถว
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 230      2401162CPV9WR0                          NaN 2024-01-16 12:32:00
# 260      2401150DMJKCH3                          NaN 2024-01-15 17:44:00
# 585      24011637TYV547                          NaN 2024-01-16 20:38:00
# 586      24011637TYV547                          NaN 2024-01-16 20:38:00
# 745      2401174YJBSEAU                          NaN 2024-01-17 13:15:00
# ...                 ...                          ...                 ...
# 65740    250331342UKT3P                          NaN 2025-03-31 15:04:00
# 65783    250329UN4QARNY                          NaN 2025-03-29 19:27:00
# 65790    2503313W80YU18                          NaN 2025-03-31 22:34:00
# 65835    2503312KU1MU9D                          NaN 2025-03-31 10:13:00
# 65851    2503300C6WKYUK                          NaN 2025-03-30 12:51:00
#
# ...

# %%
import re

# Initialize 'Mecanic_cam' column with 'Normal' as default
shopee1['Mecanic_cam'] = 'Normal'

# Define keyword categories and their corresponding patterns
categories = {
    'Double Day': [
        '[Double Day 1-7 ก.พ.]',
        '[Double Day 2-8 มี.ค.]'
    ],
    'Flash Sale': [
        '[Flash Sale]'
    ],
    'Mid Month': [
        '[Mid Month 11-17 มี.ค.]',
        '[Mid Month]',
        '(MID MONTH SET A)',
        '[Mid Month SET B]'
    ],
    'Pay Day': [
        '[Pay Day 25-31 มี.ค.]',
        '[Pay Day 20-28 ก.พ.]',
        '[Pay Day 25-30 เม.ย.]',
        '[PayDay ]'
    ],
    'Hello 2025': [
        '[Hello 2025 | 4-10 ม.ค.]',
        '[Hello 2025]'
    ]
}

# Apply categorization based on keywords
for category_name, keywords_list in categories.items():
    # Escape special characters in each keyword and join them with '|'
    pattern = '|'.join([re.escape(k) for k in keywords_list])

    # Create a boolean mask for rows matching the current category's pattern
    # Ensure we only update rows that are still 'Normal' or not yet categorized by a higher-priority rule if overlap exists
    mask = shopee1['ชื่อสินค้า'].str.contains(pattern, na=False, regex=True)
    shopee1.loc[mask, 'Mecanic_cam'] = category_name

# Display value counts of the new column to verify
print(shopee1['Mecanic_cam'].value_counts())

# Display head and tail of the DataFrame with the new column
print(shopee1[['ชื่อสินค้า', 'Mecanic_cam']].head())
print(shopee1[['ชื่อสินค้า', 'Mecanic_cam']].tail())
# Out:
# /tmp/ipykernel_2224/3898538325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shopee1['Mecanic_cam'] = 'Normal'
# Mecanic_cam
# Normal        93832
# Flash Sale     1202
# Pay Day         208
# Double Day      133
# Hello 2025       77
# Mid Month        28
# Name: count, dtype: int64
#                                           ชื่อสินค้า Mecanic_cam
# 0  แป้งเจ้านาง (แพคเกจใหม่) - Chaonang Perfect Br...      Normal
# 1  แป้งฝุ่นเจ้านาง - Chaonang Diamond Translucent...      Normal
# 2  รองพื้นเจ้านางแบบหลอด (15g.) - Chaonang Radian...      Normal
# 3  รองพื้นเจ้านางแบบหลอด (15g.) - Chaonang Radian...      Normal
# 4  แป้งเจ้านาง (แพคเกจใหม่) - Chaonang Perfect Br...      Normal
# ...

# %%
shopee1
# Out:
#        หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0         240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1         240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2         240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3         240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4         240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                  ...                          ...                 ...
# 118069    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 118070    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 118071    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 118072    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 118073    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#        เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
shopee1[shopee1['Mecanic_cam'] == 'Pay Day']
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 11233    2501201AY2RJVY                          NaN 2025-01-20 11:22:00
# 11332    25012025SUUGTR                          NaN 2025-01-20 19:22:00
# 11387    25012013TWF5M4                          NaN 2025-01-20 09:14:00
# 11832    2501213RN77HAJ                          NaN 2025-01-21 10:32:00
# 12019    2501213DYP34RA                          NaN 2025-01-21 07:21:00
# ...                 ...                          ...                 ...
# 65619    2503312UJ9AXRQ                          NaN 2025-03-31 12:32:00
# 65740    250331342UKT3P                          NaN 2025-03-31 15:04:00
# 65783    250329UN4QARNY                          NaN 2025-03-29 19:27:00
# 65790    2503313W80YU18                          NaN 2025-03-31 22:34:00
# 65835    2503312KU1MU9D                          NaN 2025-03-31 10:13:00
#
#       เวลาการชำระสินค้า ช่องทางการชำระเงิน ช่องทางการชำระเงิน (รายละเอียด)  \
# ...

# %%
print(shopee1.columns)
# Out:
# Index(['หมายเลขคำสั่งซื้อ', 'สถานะการคืนเงินหรือคืนสินค้า',
#        'วันที่ทำการสั่งซื้อ', 'เวลาการชำระสินค้า', 'ช่องทางการชำระเงิน',
#        'ช่องทางการชำระเงิน (รายละเอียด)', 'แผนการผ่อนชำระ', 'ค่าธรรมเนียม (%)',
#        'ตัวเลือกการจัดส่ง', '*หมายเลขติดตามพัสดุ',
#        'วันที่คาดว่าจะทำการจัดส่งสินค้า', 'เวลาส่งสินค้า', 'ชื่อสินค้า',
#        'เลขอ้างอิง SKU (SKU Reference No.)', 'ชื่อตัวเลือก', 'ราคาตั้งต้น',
#        'ราคาขาย', 'จำนวน', 'จำนวนที่ส่งคืน', 'ยอดชำระเงิน', 'ส่วนลดจาก Shopee',
#        'โค้ดส่วนลดชำระโดยผู้ขาย',
#        'โค้ดส่วนลดชำระโดย Shopee (เช่น โค้ดจากโปรแกรม ร้านโค้ดคุ้ม, โค้ดส่วนลด Shopee, โค้ดส่วนลด Shopee Mall)',
#        'ส่วนลดจากการใช้เหรียญ', 'ค่าคอมมิชชั่น',
#        'ราคาสินค้าที่ชำระโดยผู้ซื้อ (THB)', 'ค่าบริการ', 'จำนวนเงินทั้งหมด',
#        'ค่าจัดส่งโดยประมาณ', 'ประเทศ', 'จังหวัด', 'เขต/อำเภอ',
#        'เวลาที่ทำการสั่งซื้อสำเร็จ', 'SKU', 'Mecanic_cam'],
#       dtype='object')

# %%
output_path = '/content/drive/MyDrive/intern CHN/shopee_processed_data.xlsx'
shopee1.to_excel(output_path, index=False)
print(f"DataFrame 'shopee1' ถูกส่งออกไปยัง '{output_path}' เรียบร้อยแล้ว")
# Out:
# DataFrame 'shopee1' ถูกส่งออกไปยัง '/content/drive/MyDrive/intern CHN/shopee_processed_data.xlsx' เรียบร้อยแล้ว

# %% [markdown]
# ## Discount

# %%
file_path_99 = '/content/drive/MyDrive/intern CHN/shopee_processed_data.xlsx'

# %%
shopee2 =  pd.read_excel(file_path_99)

# %%
print(shopee2.columns)
# Out:
# Index(['หมายเลขคำสั่งซื้อ', 'สถานะการคืนเงินหรือคืนสินค้า',
#        'วันที่ทำการสั่งซื้อ', 'เวลาการชำระสินค้า', 'ช่องทางการชำระเงิน',
#        'ช่องทางการชำระเงิน (รายละเอียด)', 'แผนการผ่อนชำระ', 'ค่าธรรมเนียม (%)',
#        'ตัวเลือกการจัดส่ง', '*หมายเลขติดตามพัสดุ',
#        'วันที่คาดว่าจะทำการจัดส่งสินค้า', 'เวลาส่งสินค้า', 'ชื่อสินค้า',
#        'เลขอ้างอิง SKU (SKU Reference No.)', 'ชื่อตัวเลือก', 'ราคาตั้งต้น',
#        'ราคาขาย', 'จำนวน', 'จำนวนที่ส่งคืน', 'ยอดชำระเงิน', 'ส่วนลดจาก Shopee',
#        'โค้ดส่วนลดชำระโดยผู้ขาย',
#        'โค้ดส่วนลดชำระโดย Shopee (เช่น โค้ดจากโปรแกรม ร้านโค้ดคุ้ม, โค้ดส่วนลด Shopee, โค้ดส่วนลด Shopee Mall)',
#        'ส่วนลดจากการใช้เหรียญ', 'ค่าคอมมิชชั่น',
#        'ราคาสินค้าที่ชำระโดยผู้ซื้อ (THB)', 'ค่าบริการ', 'จำนวนเงินทั้งหมด',
#        'ค่าจัดส่งโดยประมาณ', 'ประเทศ', 'จังหวัด', 'เขต/อำเภอ',
#        'เวลาที่ทำการสั่งซื้อสำเร็จ', 'SKU', 'Mecanic_cam'],
#       dtype='object')

# %%
shopee2.columns = shopee2.columns.str.replace(' ', '_')
print("ชื่อคอลัมน์ของ shopee2 ถูกเปลี่ยนเป็น:")
print(shopee2.columns)
# Out:
# ชื่อคอลัมน์ของ shopee2 ถูกเปลี่ยนเป็น:
# Index(['หมายเลขคำสั่งซื้อ', 'สถานะการคืนเงินหรือคืนสินค้า',
#        'วันที่ทำการสั่งซื้อ', 'เวลาการชำระสินค้า', 'ช่องทางการชำระเงิน',
#        'ช่องทางการชำระเงิน_(รายละเอียด)', 'แผนการผ่อนชำระ', 'ค่าธรรมเนียม_(%)',
#        'ตัวเลือกการจัดส่ง', '*หมายเลขติดตามพัสดุ',
#        'วันที่คาดว่าจะทำการจัดส่งสินค้า', 'เวลาส่งสินค้า', 'ชื่อสินค้า',
#        'เลขอ้างอิง_SKU_(SKU_Reference_No.)', 'ชื่อตัวเลือก', 'ราคาตั้งต้น',
#        'ราคาขาย', 'จำนวน', 'จำนวนที่ส่งคืน', 'ยอดชำระเงิน', 'ส่วนลดจาก_Shopee',
#        'โค้ดส่วนลดชำระโดยผู้ขาย',
#        'โค้ดส่วนลดชำระโดย_Shopee_(เช่น_โค้ดจากโปรแกรม_ร้านโค้ดคุ้ม,_โค้ดส่วนลด_Shopee,_โค้ดส่วนลด_Shopee_Mall)',
#        'ส่วนลดจากการใช้เหรียญ', 'ค่าคอมมิชชั่น',
#        'ราคาสินค้าที่ชำระโดยผู้ซื้อ_(THB)', 'ค่าบริการ', 'จำนวนเงินทั้งหมด',
#        'ค่าจัดส่งโดยประมาณ', 'ประเทศ', 'จังหวัด', 'เขต/อำเภอ',
#        'เวลาที่ทำการสั่งซื้อสำเร็จ', 'SKU', 'Mecanic_cam'],
#       dtype='object')

# %%
import re

# Define the keyword to search for, escaping special characters
keyword_to_search = re.escape('(ของแถม)')

# Filter the DataFrame to find rows where 'ชื่อสินค้า' contains the keyword
matching_rows_count = shopee2['ชื่อสินค้า'].str.contains(keyword_to_search, na=False, regex=True).sum()

print(f"จำนวนแถวในคอลัมน์ 'ชื่อสินค้า' ที่มีคำว่า '(ของแถม)': {matching_rows_count} แถว")
# Out:
# จำนวนแถวในคอลัมน์ 'ชื่อสินค้า' ที่มีคำว่า '(ของแถม)': 0 แถว

# %%
import re

# Define the keyword to search for, escaping special characters
keyword_to_search = re.escape('(ของแถม)')

# Create a boolean mask for rows that contain the keyword
mask_to_drop = shopee2['ชื่อสินค้า'].str.contains(keyword_to_search, na=False, regex=True)

# Drop the rows that match the mask
shopee2 = shopee2[~mask_to_drop]

print(f"DataFrame 'shopee2' หลังจากลบ 9 แถว: {shopee2.shape[0]} แถว และ {shopee2.shape[1]} คอลัมน์")
# Out:
# DataFrame 'shopee2' หลังจากลบ 9 แถว: 95480 แถว และ 35 คอลัมน์

# %%
duplicate_orders = shopee2['หมายเลขคำสั่งซื้อ'].value_counts()
duplicate_order_rows = duplicate_orders[duplicate_orders > 1].sum()

print(f"จำนวนแถวที่มีหมายเลขคำสั่งซื้อซ้ำกันคือ: {duplicate_order_rows} แถว")
# Out:
# จำนวนแถวที่มีหมายเลขคำสั่งซื้อซ้ำกันคือ: 26514 แถว

# %%
unique_orders_count = shopee2['หมายเลขคำสั่งซื้อ'].nunique()
print(f"จำนวนแถวที่มีหมายเลขคำสั่งซื้อที่ไม่ซ้ำกันคือ: {unique_orders_count} แถว")
# Out:
# จำนวนแถวที่มีหมายเลขคำสั่งซื้อที่ไม่ซ้ำกันคือ: 80715 แถว

# %% [markdown]
# 1. จำนวนแถวทั้งหมดใน DataFrame shopee2: 95471 แถว
# 2. จำนวนหมายเลขคำสั่งซื้อที่ไม่ซ้ำกันทั้งหมด (Distinct Order IDs): 80715
# 68971+11744
# 3. จำนวนแถวที่มีหมายเลขคำสั่งซื้อปรากฏเพียงครั้งเดียว: 68971 แถว เลขที่ไม่ซ้ำแล้วก็ไม่ได้รวมเลขที่นับซ้ำด้วย 95471-26500
# 4. จำนวนแถวที่มีหมายเลขคำสั่งซื้อปรากฏมากกว่าหนึ่งครั้ง: 26500 แถว
# 5. จำนวนหมายเลขคำสั่งซื้อที่มีการซ้ำกัน (Distinct Order IDs with Duplicates): 11744 หมายเลข (นี่คือจำนวนหมายเลขคำสั่งซื้อที่แตกต่างกันที่ปรากฏมากกว่าหนึ่งครั้งในข้อมูล)

# %%
duplicate_orders = shopee2['หมายเลขคำสั่งซื้อ'].value_counts()
duplicate_order_rows = duplicate_orders[duplicate_orders > 1].sum()
unique_orders_count = shopee2['หมายเลขคำสั่งซื้อ'].nunique()

print(f"จำนวนแถวที่มีหมายเลขคำสั่งซื้อซ้ำกันคือ: {duplicate_order_rows} แถว")
print(f"จำนวนหมายเลขคำสั่งซื้อที่ไม่ซ้ำกัน (Distinct Order IDs) คือ: {unique_orders_count} หมายเลข")
# Out:
# จำนวนแถวที่มีหมายเลขคำสั่งซื้อซ้ำกันคือ: 26514 แถว
# จำนวนหมายเลขคำสั่งซื้อที่ไม่ซ้ำกัน (Distinct Order IDs) คือ: 80715 หมายเลข

# %% [markdown]
# ## รวมรหัสสินค้า
# เพื่อดู Discount % ทั้งบิล

# %%
from numpy import mean
new_shopee_data = shopee2.groupby('หมายเลขคำสั่งซื้อ').agg(
    ยอดขายรวม=('ราคาขาย', 'sum'),
    ส่วนลดผู้ขาย=('โค้ดส่วนลดชำระโดยผู้ขาย','mean'),
    ส่วนลด_Shopee=('โค้ดส่วนลดชำระโดย_Shopee_(เช่น_โค้ดจากโปรแกรม_ร้านโค้ดคุ้ม,_โค้ดส่วนลด_Shopee,_โค้ดส่วนลด_Shopee_Mall)','mean')
).reset_index()

new_shopee_data['ส่วนลดรวม'] = new_shopee_data['ส่วนลดผู้ขาย'] + new_shopee_data['ส่วนลด_Shopee']

# Drop the intermediate discount columns if they are not needed separately
new_shopee_data = new_shopee_data.drop(columns=['ส่วนลดผู้ขาย', 'ส่วนลด_Shopee'])

# Rename the 'หมายเลขคำสั่งซื้อ' column to 'หมายเลขคำสั่งซื้อรวม'
new_shopee_data = new_shopee_data.rename(columns={'หมายเลขคำสั่งซื้อ': 'หมายเลขคำสั่งซื้อรวม'})

print("ตารางข้อมูลใหม่ 'new_shopee_data' ถูกสร้างขึ้นแล้ว:")
print(new_shopee_data.head())
print(f"จำนวนแถว: {new_shopee_data.shape[0]}, จำนวนคอลัมน์: {new_shopee_data.shape[1]}")
# Out:
# ตารางข้อมูลใหม่ 'new_shopee_data' ถูกสร้างขึ้นแล้ว:
#   หมายเลขคำสั่งซื้อรวม  ยอดขายรวม  ส่วนลดรวม
# 0       240102SP39BMES        374       75.0
# 1       240102SRPHXTVH        380      100.0
# 2       240102SVCS34FQ        564        0.0
# 3       240102SVN27JNU        380        0.0
# 4       240102T3HW191Y        175      100.0
# จำนวนแถว: 80715, จำนวนคอลัมน์: 3

# %%
new_shopee_data[new_shopee_data['หมายเลขคำสั่งซื้อรวม'] == '2401078EYC6AU1']
# Out:
#    หมายเลขคำสั่งซื้อรวม  ยอดขายรวม  ส่วนลดรวม
# 93       2401078EYC6AU1        754      100.0

# %%
output_path_new_data = '/content/drive/MyDrive/intern CHN/new_shopee_data.xlsx'
new_shopee_data.to_excel(output_path_new_data, index=False)
print(f"DataFrame 'new_shopee_data' ถูกส่งออกไปยัง '{output_path_new_data}' เรียบร้อยแล้ว")
# Out:
# DataFrame 'new_shopee_data' ถูกส่งออกไปยัง '/content/drive/MyDrive/intern CHN/new_shopee_data.xlsx' เรียบร้อยแล้ว

# %%
file_path_98 = '/content/drive/MyDrive/intern CHN/new_shopee_data (1).xlsx'
alldis =  pd.read_excel(file_path_98)

# %%
alldis
# Out:
#       หมายเลขคำสั่งซื้อรวม  ยอดขายรวม  ส่วนลดรวม  ราคาลูกค้าจ่าย    Disรวม%
# 0           240102SP39BMES        374         75             299  20.053476
# 1           240102SRPHXTVH        380        100             280  26.315789
# 2           240102SVCS34FQ        564          0             564   0.000000
# 3           240102SVN27JNU        380          0             380   0.000000
# 4           240102T3HW191Y        175        100              75  57.142857
# ...                    ...        ...        ...             ...        ...
# 80710       260401KMT1TK9D        349         85             264  24.355301
# 80711       260401KMTCB3NA        209         83             126  39.712919
# 80712       260401KMUCRTYX        118         21              97  17.796610
# 80713       260401KMX4FVBY        349         70             279  20.057307
# 80714       260401KN1TTP9K        159         62              97  38.993711
#
# [80715 rows x 5 columns]

# %%
import pandas as pd

# Create a temporary DataFrame with unique order IDs and their corresponding dates from shopee2
# This is necessary because shopee2 might have multiple rows per order (for different items),
# but alldis has one row per unique order ID.
order_dates = shopee2[['หมายเลขคำสั่งซื้อ', 'วันที่ทำการสั่งซื้อ']].drop_duplicates(subset=['หมายเลขคำสั่งซื้อ'])

# Merge alldis with order_dates to add the 'วันที่ทำการสั่งซื้อ' column
# Use a left merge to keep all rows from alldis
alldis = pd.merge(alldis, order_dates, left_on='หมายเลขคำสั่งซื้อรวม', right_on='หมายเลขคำสั่งซื้อ', how='left')

# Drop the redundant 'หมายเลขคำสั่งซื้อ' column that resulted from the merge
alldis = alldis.drop(columns=['หมายเลขคำสั่งซื้อ'])

print("DataFrame 'alldis' หลังจากเพิ่มคอลัมน์ 'วันที่ทำการสั่งซื้อ':")
print(alldis.head())
print(f"จำนวนแถว: {alldis.shape[0]}, จำนวนคอลัมน์: {alldis.shape[1]}")
# Out:
# DataFrame 'alldis' หลังจากเพิ่มคอลัมน์ 'วันที่ทำการสั่งซื้อ':
#   หมายเลขคำสั่งซื้อรวม  ยอดขายรวม  ส่วนลดรวม  ราคาลูกค้าจ่าย    Disรวม%  \
# 0       240102SP39BMES        374         75             299  20.053476
# 1       240102SRPHXTVH        380        100             280  26.315789
# 2       240102SVCS34FQ        564          0             564   0.000000
# 3       240102SVN27JNU        380          0             380   0.000000
# 4       240102T3HW191Y        175        100              75  57.142857
#
#   วันที่ทำการสั่งซื้อ
# 0 2024-01-02 15:18:00
# 1 2024-01-02 16:05:00
# 2 2024-01-02 17:11:00
# 3 2024-01-02 17:16:00
# 4 2024-01-02 19:19:00
# จำนวนแถว: 80715, จำนวนคอลัมน์: 6

# %%
alldis
# Out:
#       หมายเลขคำสั่งซื้อรวม  ยอดขายรวม  ส่วนลดรวม  ราคาลูกค้าจ่าย    Disรวม%  \
# 0           240102SP39BMES        374         75             299  20.053476
# 1           240102SRPHXTVH        380        100             280  26.315789
# 2           240102SVCS34FQ        564          0             564   0.000000
# 3           240102SVN27JNU        380          0             380   0.000000
# 4           240102T3HW191Y        175        100              75  57.142857
# ...                    ...        ...        ...             ...        ...
# 80710       260401KMT1TK9D        349         85             264  24.355301
# 80711       260401KMTCB3NA        209         83             126  39.712919
# 80712       260401KMUCRTYX        118         21              97  17.796610
# 80713       260401KMX4FVBY        349         70             279  20.057307
# 80714       260401KN1TTP9K        159         62              97  38.993711
#
#       วันที่ทำการสั่งซื้อ
# 0     2024-01-02 15:18:00
# ...

# %%
shopee2
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#       เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %% [markdown]
# ## preparation

# %% [markdown]
# สมมติว่าต้องการหายอดขายรวมทั้งหมดของบริษัท
# Drop duplicates ให้เหลือ OrderID ละ 1 บรรทัด
# unique_orders = df_all.drop_duplicates(subset=['Order ID'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Drop duplicates based on 'หมายเลขคำสั่งซื้อ' to get one row per unique order
shopee2_dropdup = shopee2.drop_duplicates(subset=['หมายเลขคำสั่งซื้อ']).copy()

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2_dropdup['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2_dropdup['วันที่ทำการสั่งซื้อ'])

# Extract the year from the 'วันที่ทำการสั่งซื้อ' column
shopee2_dropdup['Year'] = shopee2_dropdup['วันที่ทำการสั่งซื้อ'].dt.year

# Calculate total sales per year using 'ยอดชำระเงิน'
sales_by_year_shopee2 = shopee2_dropdup.groupby('Year')['ยอดชำระเงิน'].sum().reset_index()

# Create the bar chart
fig, ax = plt.subplots(figsize=(10, 6))
bar_container = ax.bar(sales_by_year_shopee2['Year'], sales_by_year_shopee2['ยอดชำระเงิน'], color='green')

# Set labels and title dynamically
ax.set_xlabel('Year')
ax.set_ylabel('Total Order Amount (THB)')
ax.set_title('Total Sales per Year from Shopee2 Data')
ax.set_ylim(0, sales_by_year_shopee2['ยอดชำระเงิน'].max() * 1.1) # Dynamic y-axis limit
ax.set_xticks(sales_by_year_shopee2['Year']) # Ensure all years are displayed as ticks
ax.tick_params(axis='x', rotation=45)
ax.grid(axis='y', linestyle='--', alpha=0.7)

ax.bar_label(bar_container, fmt='{:,.0f}')

plt.tight_layout()
plt.show()
print("ยอดขายรวมต่อปีจาก shopee2:")
print(sales_by_year_shopee2)
# Out:
# ยอดขายรวมต่อปีจาก shopee2:
#    Year  ยอดชำระเงิน
# 0  2024      1365723
# 1  2025      9523594
# 2  2026     10652301

# %%
shopee2_dropdup.groupby('Year')['ยอดชำระเงิน'].sum()
# Out:
# Year
# 2024     1365723
# 2025     9523594
# 2026    10652301
# Name: ยอดชำระเงิน, dtype: int64

# %%
shopee2_dropdup['Year'].unique()
# Out:
# array([2024, 2025, 2026], dtype=int32)

# %%
shopee2_dropdup.shape
# Out:
# (80715, 36)

# %%
shopee2.shape
# Out:
# (95480, 35)

# %%
output_path_shopee2 = '/content/drive/MyDrive/intern CHN/shopee2.xlsx'
shopee2.to_excel(output_path_shopee2, index=False)
print(f"DataFrame 'shopee2' ถูกส่งออกไปยัง '{output_path_shopee2}' เรียบร้อยแล้ว")

output_path_shopee2_dropdup = '/content/drive/MyDrive/intern CHN/shopee2_dropdup.xlsx'
shopee2_dropdup.to_excel(output_path_shopee2_dropdup, index=False)
print(f"DataFrame 'shopee2_dropdup' ถูกส่งออกไปยัง '{output_path_shopee2_dropdup}' เรียบร้อยแล้ว")
# Out:
# DataFrame 'shopee2' ถูกส่งออกไปยัง '/content/drive/MyDrive/intern CHN/shopee2.xlsx' เรียบร้อยแล้ว
# DataFrame 'shopee2_dropdup' ถูกส่งออกไปยัง '/content/drive/MyDrive/intern CHN/shopee2_dropdup.xlsx' เรียบร้อยแล้ว

# %%
output_path_alldis = '/content/drive/MyDrive/intern CHN/aldis.xlsx'
alldis.to_excel(output_path_alldis, index=False)
print(f"DataFrame 'alldis' ถูกส่งออกไปยัง '{output_path_alldis}' เรียบร้อยแล้ว")
# Out:
# DataFrame 'alldis' ถูกส่งออกไปยัง '/content/drive/MyDrive/intern CHN/aldis.xlsx' เรียบร้อยแล้ว

# %% [markdown]
# ## วิเคราะห์ด้านยอดขาย

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = shopee2.copy()

# =========================
# DATE COLUMN
# =========================
date_cols = [
    'วันที่ทำการสั่งซื้อ',
    'เวลาการชำระสินค้า',
    'วันที่คาดว่าจะทำการจัดส่งสินค้า',
    'เวลาส่งสินค้า',
    'เวลาที่ทำการสั่งซื้อสำเร็จ'
]

for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# =========================
# NUMERIC COLUMN
# =========================
num_cols = [
    'ราคาตั้งต้น',
    'ราคาขาย',
    'จำนวน',
    'จำนวนที่ส่งคืน',
    'ยอดชำระเงิน',
    'ส่วนลดจาก_Shopee',
    'โค้ดส่วนลดชำระโดยผู้ขาย',
    'โค้ดส่วนลดชำระโดย_Shopee_(เช่น_โค้ดจากโปรแกรม_ร้านโค้ดคุ้ม,_โค้ดส่วนลด_Shopee,_โค้ดส่วนลด_Shopee_Mall)',
    'ส่วนลดจากการใช้เหรียญ',
    'ค่าคอมมิชชั่น',
    'ราคาสินค้าที่ชำระโดยผู้ซื้อ_(THB)',
    'ค่าบริการ',
    'จำนวนเงินทั้งหมด',
    'ค่าจัดส่งโดยประมาณ',
    'ค่าธรรมเนียม_(%)'
]

for col in num_cols:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace(',', '')
        .str.replace('฿', '')
    )

    df[col] = pd.to_numeric(df[col], errors='coerce')

# =========================
# CREATE NEW COLUMN
# =========================

df['month'] = df['วันที่ทำการสั่งซื้อ'].dt.month
df['weekday'] = df['วันที่ทำการสั่งซื้อ'].dt.day_name()
df['hour'] = df['เวลาการชำระสินค้า'].dt.hour

df['ส่วนลดรวม'] = (
    + df['โค้ดส่วนลดชำระโดยผู้ขาย'].fillna(0)
    + df['โค้ดส่วนลดชำระโดย_Shopee_(เช่น_โค้ดจากโปรแกรม_ร้านโค้ดคุ้ม,_โค้ดส่วนลด_Shopee,_โค้ดส่วนลด_Shopee_Mall)'].fillna(0)
)

df['gross_sales'] = df['ราคาขาย'] * df['จำนวน']

df['net_sales'] = (
    df['จำนวนเงินทั้งหมด']
    - df['ค่าคอมมิชชั่น']
    - df['ค่าบริการ']
)

df['estimated_profit'] = (
    df['จำนวนเงินทั้งหมด']
    - df['ส่วนลดรวม']
    - df['ค่าคอมมิชชั่น']
    - df['ค่าบริการ']
    - df['ค่าจัดส่งโดยประมาณ']
)

# %%
# Return Flag
df['return_flag'] = np.where(df['จำนวนที่ส่งคืน'] > 0, 1, 0)

# Shipping Delay
df['processing_day'] = (
    df['เวลาส่งสินค้า']
    - df['เวลาการชำระสินค้า']
).dt.days

# %%
df
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#         เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
try:
    order_df = alldis.copy()
except:
    order_df = df.drop_duplicates(subset='หมายเลขคำสั่งซื้อ')

# %%
print(df['group'].value_counts(dropna=False))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'group'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2224/1458528305.py in <cell line: 0>()
# ----> 1 print(df['group'].value_counts(dropna=False))
#
# ...

# %%
# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2.loc[:, 'วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Get the mask for 2025 entries
is_2025 = (shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2025)

# Apply 'newset' for specified products in 2025
shopee2.loc[is_2025 & (shopee2['ชื่อสินค้า'].isin(newset)), 'SKU'] = 'newset'

# Apply 'oldset' for other products in 2025
shopee2.loc[is_2025 & (~shopee2['ชื่อสินค้า'].isin(newset)), 'SKU'] = 'oldset'

print("Updated SKU counts for 2025 entries:")
print(shopee2.loc[shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2025, 'SKU'].value_counts(dropna=False))

print("\nOverall SKU counts after update:")
print(shopee2['SKU'].value_counts(dropna=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2224/2483947127.py in <cell line: 0>()
#       6
#       7 # Apply 'newset' for specified products in 2025
# ----> 8 shopee2.loc[is_2025 & (shopee2['ชื่อสินค้า'].isin(newset)), 'SKU'] = 'newset'
#       9
#      10 # Apply 'oldset' for other products in 2025
#
# NameError: name 'newset' is not defined

# %%
import matplotlib.pyplot as plt

# =========================================
# 1. SALES BY SKU TYPE (เก่า/ใหม่)
# =========================================

sku_sales = (
    df.groupby('SKU')['net_sales']
    .sum()
    .sort_values(ascending=False)
)

print(sku_sales.head())

fig, ax = plt.subplots(figsize=(12, 5))
bars = ax.bar(sku_sales.index, sku_sales.values)
ax.set_title('Sales by SKU')
ax.set_xlabel('SKU')
ax.set_ylabel('Net Sales')

# Add numerical labels on top of the bars
ax.bar_label(bars, fmt='{:,.0f}')

plt.tight_layout()
plt.show()

# %%
merged_df = pd.merge(df, shopee2_dropdup[['หมายเลขคำสั่งซื้อ', 'Year']], on='หมายเลขคำสั่งซื้อ', how='left')

# Group by Year and group and sum the net_sales
sku_sales_by_year = merged_df.groupby(['Year', 'group'])['net_sales'].sum().unstack()

# Plotting the data
fig, ax = plt.subplots(figsize=(14, 7))
sku_sales_by_year.plot(kind='bar', ax=ax, rot=0)

ax.set_title('Net Sales by Year and Product Group')
ax.set_xlabel('Year')
ax.set_ylabel('Net Sales')
ax.legend(title='Product Group')
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Add numerical labels on top of the bars
for container in ax.containers:
    ax.bar_label(container, fmt='{:,.0f}')

plt.tight_layout()
plt.show()

display(sku_sales_by_year)

# %% [markdown]
# ## แก้ไฟล์

# %%
file_path100 = '/content/drive/MyDrive/intern CHN/shopee2.xlsx'
file_path101 = '/content/drive/MyDrive/intern CHN/new_shopee_data (1).xlsx'

# %%
shopee2 = pd.read_excel(file_path100)
discount = pd.read_excel(file_path101)

# %%
shopee2
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#       เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
shopee2_dropdup
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# 5        240102TCV8869T                          NaN 2024-01-02 22:06:00
# 6        2401040WQKYE7R                          NaN 2024-01-04 08:45:00
# ...                 ...                          ...                 ...
# 95474    260331KAX7SPNF                          NaN 2026-03-31 20:56:00
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#       เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
shopee2 = shopee2.drop(columns=['SKU'])
print("The 'SKU' column has been dropped from the DataFrame.")
# Out:
# The 'SKU' column has been dropped from the DataFrame.

# %%
shopee2
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#       เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
shopee2 = shopee2.drop(columns=['Discount %',])
print("The 'SKU' column has been dropped from the DataFrame.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2224/1556511875.py in <cell line: 0>()
# ----> 1 shopee2 = shopee2.drop(columns=['Discount %',])
#       2 print("The 'SKU' column has been dropped from the DataFrame.")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
# ...

# %%
shopee2 = shopee2.drop(columns=['Unnamed: 32'])
print("The 'SKU' column has been dropped from the DataFrame.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2224/3600234745.py in <cell line: 0>()
# ----> 1 shopee2 = shopee2.drop(columns=['Unnamed: 32'])
#       2 print("The 'SKU' column has been dropped from the DataFrame.")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
# ...

# %%
shopee2 = shopee2.drop(columns=['ยอดจริงๆ'])
print("The 'SKU' column has been dropped from the DataFrame.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2224/2894923134.py in <cell line: 0>()
# ----> 1 shopee2 = shopee2.drop(columns=['ยอดจริงๆ'])
#       2 print("The 'SKU' column has been dropped from the DataFrame.")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
# ...

# %%
shopee2
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#       เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
import re

# Define the keyword to search for, escaping special characters
keyword_to_search = re.escape('(ของแถม)')

# Filter the DataFrame to find rows where 'ชื่อสินค้า' contains the keyword
filtered_items = shopee2[shopee2['ชื่อสินค้า'].str.contains(keyword_to_search, na=False, regex=True)]

print(f"จำนวนแถวในคอลัมน์ 'ชื่อสินค้า' ที่มีคำว่า '(ของแถม)': {len(filtered_items)} แถว")

# Display the filtered DataFrame
filtered_items
# Out:
# จำนวนแถวในคอลัมน์ 'ชื่อสินค้า' ที่มีคำว่า '(ของแถม)': 0 แถว
# Empty DataFrame
# Columns: [หมายเลขคำสั่งซื้อ, สถานะการคืนเงินหรือคืนสินค้า, วันที่ทำการสั่งซื้อ, เวลาการชำระสินค้า, ช่องทางการชำระเงิน, ช่องทางการชำระเงิน_(รายละเอียด), แผนการผ่อนชำระ, ค่าธรรมเนียม_(%), ตัวเลือกการจัดส่ง, *หมายเลขติดตามพัสดุ, วันที่คาดว่าจะทำการจัดส่งสินค้า, เวลาส่งสินค้า, ชื่อสินค้า, เลขอ้างอิง_SKU_(SKU_Reference_No.), ชื่อตัวเลือก, ราคาตั้งต้น, ราคาขาย, จำนวน, จำนวนที่ส่งคืน, ยอดชำระเงิน, ส่วนลดจาก_Shopee, โค้ดส่วนลดชำระโดยผู้ขาย, โค้ดส่วนลดชำระโดย_Shopee_(เช่น_โค้ดจากโปรแกรม_ร้านโค้ดคุ้ม,_โค้ดส่วนลด_Shopee,_โค้ดส่วนลด_Shopee_Mall), ส่วนลดจากการใช้เหรียญ, ค่าคอมมิชชั่น, ราคาสินค้าที่ชำระโดยผู้ซื้อ_(THB), ค่าบริการ, จำนวนเงินทั้งหมด, ค่าจัดส่งโดยประมาณ, ประเทศ, จังหวัด, เขต/อำเภอ, เวลาที่ทำการสั่งซื้อสำเร็จ, Mecanic_cam]
# Index: []
#
# [0 rows x 34 columns]

# %%
import re

# Define the keyword to search for, escaping special characters
keyword_to_search = re.escape('(ของแถม)')

# Create a boolean mask for rows that contain the keyword
mask_to_drop = shopee2['ชื่อสินค้า'].str.contains(keyword_to_search, na=False, regex=True)

# Drop the rows that match the mask
shopee2 = shopee2[~mask_to_drop]

print(f"DataFrame 'shopee2' หลังจากลบแถวที่มี '(ของแถม)': {shopee2.shape[0]} แถว และ {shopee2.shape[1]} คอลัมน์")
# Out:
# DataFrame 'shopee2' หลังจากลบแถวที่มี '(ของแถม)': 95480 แถว และ 34 คอลัมน์

# %%
shopee2['group'] = None
print("The 'group' column has been created and initialized with None values.")
# Out:
# The 'group' column has been created and initialized with None values.

# %%
import pandas as pd

# Define the list of products to be categorized as 'old' for 2024
old_products_2024 = [
    'อายไลเนอร์เจ้านาง -  Chaonang Long-Lating Waterproof Eyeliner',
    'ลิปจุ่มเจ้านาง - Liquid Lip Chaonang Ultimate Velvet Lip',
    'รองพื้นเจ้านางแบบหลอด (15g.) - Chaonang Radiance Skin Foundation SPF30 PA+++',
    'รองพื้นเจ้านางแบบกล่อง (กล่อง/6ซอง) - Chaonang Radiance Skin Foundation SPF30 PA+++',
    'รองพื้นเจ้านางแบบซอง(5g.) - Chaonang Radiance Skin Foundation SPF30 PA+++',
    'พัฟฟองน้ำเจ้านาง - Chaonang Puff',
    'ฟองน้ำรูปไข่ - Chaonang soft blending make up sponge',
    'แป้งเจ้านาง (แพคเกจใหม่) - Chaonang Perfect Bright UV 2-way Powder Foundation',
    'แป้งฝุ่นเจ้านาง - Chaonang Diamond Translucent Powder',
    'ดินสอเขียนคิ้วเจ้านาง - Chaonang Slim Waterproof Eyebrow',
    'คุชชั่นเจ้านาง - Chaonang glowy cushion spf30 pa+++'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2024 and match the specified products
is_2024 = (shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2024)
matches_products = shopee2['ชื่อสินค้า'].isin(old_products_2024)

# Apply the 'old' categorization to the 'group' column for matching rows
shopee2.loc[is_2024 & matches_products, 'group'] = 'old'

print("Updated 'group' column for 2024 products:")
print(shopee2['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for 2024 products:
# group
# None    91238
# old      4242
# Name: count, dtype: int64

# %%
oldset_products_2024 = [
    '[Mid Month SET B] แป้งพัฟเจ้านาง + ลิปจุ่มเจ้านาง แถม ดินสอเขียนคิ้วหรืออายไลเนอร์',
    '[Chaonang Set] แป้งฝุ่นเจ้านาง + รองพื้นหลอด 15 g.',
    '[Chaonang Set] แป้งพัฟเจ้านาง(แพคเกจใหม่) + รองพื้นหลอด 15g.',
    '[Chaonang Set] แป้งพัฟเจ้านาง(แบบ 2 ชั้น) + รองพื้นหลอด 15g.',
    '(MID MONTH SET A) คุชชั่นเจ้านาง คู่กับ ลิปจุ่มเจ้านาง แถมฟรีดินสอเขียนคิ้วหรืออายไลนเนอร์',
    '[Mid Month] แป้งพัฟเจ้านาง(แพคเกจใหม่) + รองพื้นหลอด15g. แถมฟรีฟองน้ำไข่',
    '[Mid Month] แป้งพัฟเจ้านาง(แพคเกจใหม่) คู่กับ ลิปจุ่มเจ้านาง',
    '[Pay Day] แป้งฝุ่น + รองพื้นหลอด15g. + แถมดินสอเขียนคิ้ว/อายไลเนอร์',
    '[Pay Day] แป้งพัฟเจ้านา(แพคเกจใหม่) + รองพื้นหลอด15g. แถมดินสอเขียนคิ้ว หรือ อายไลเนอร์',
    '[Pay Day] แป้งพัฟเจ้านาง(แพคเกจใหม่) + รองพื้นหลอด15g. แถมดินสอเขียนคิ้ว หรือ อายไลเนอร์',
    '[Set 3.3] แป้งฝุ่นเจ้านาง คู่กับ ลิปจุ่มเจ้านาง แถมดินสอเขียนคิ้ว หรือ อายไลเนอร์',
    '[Set 3.3] แป้งพัฟ(แพคเกจใหม่) + รองพื้นหลอด + ลิปจุ่ม',
    '[Set 3.3] แป้งพัฟ(แพคเกจใหม่) คู่กับ แป้งฝุ่น แถมดินสอเขียนคิ้ว หรือ อายไลเนอร์',
    '[Special Set] คุชชั่นเจ้านาง คู่กับ แป้งฝุ่นเจ้านาง',
    '[Valentine Set] คุชชั่นเจ้านาง คู่กับ ลิปจุ่มเจ้านาง',
    '[Valentine Set] แป้งฝุ่นเจ้านาง คู่กับ ลิปจุ่มเจ้านาง',
    '[Valentine Set] แป้งพัฟเจ้านาง(แพคเกจใหม่) คู่กับ ลิปจุ่มเจ้านาง',
    '[Velentine Set] แป้งพัฟเจ้านาง(แพคเกจใหม่) คู่กับ ลิปจุ่มเจ้านาง',
    'Box Set ลิปจุ่มเจ้านาง 5 เฉดสี - Liquid Lip Chaonang Ultimate Velvet Lip Set',
    'Set ตรุษจีน รองพื้นหลอด15g. + ลิปจุ่ม',
    'คุชชั่นเจ้านาง - Chaonang glowy cushion spf30 pa+++',
    'เซตคู่สุดคุ้ม แป้งพัฟ+อายไลเนอร์'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2024 and match the specified products
is_2024 = (shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2024)
matches_products_oldset = shopee2['ชื่อสินค้า'].isin(oldset_products_2024)

# Apply the 'oldset' categorization to the 'group' column for matching rows
shopee2.loc[is_2024 & matches_products_oldset, 'group'] = 'oldset'

print("Updated 'group' column for 2024 products (oldset category):")
print(shopee2['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for 2024 products (oldset category):
# group
# None      90888
# old        3309
# oldset     1283
# Name: count, dtype: int64

# %%
products_to_categorize_as_old_2025 = [
    'ลิปจุ่มเจ้านาง (3ก.) - Chaonang Liquid Lip Chaonang Ultimate Velvet Lip 3g. (หมดอายุ 6/2025)',
    'ลิปจุ่มเจ้านาง (3ก.) - Chaonang Liquid Lip Chaonang Ultimate Velvet Lip 3g. exp.22/5/2025',
    'อายไลเนอร์เจ้านาง -  Chaonang Long-Lating Waterproof Eyeliner',
    'รองพื้นเจ้านางแบบกล่อง (1 กล่อง) - Chaonang Radiance Skin Foundation SPF30 PA+++ (1 Box)',
    'รองพื้นเจ้านางแบบกล่อง (กล่อง/6ซอง) - Chaonang Radiance Skin Foundation SPF30 PA+++',
    'รองพื้นเจ้านาง แบบซอง (5ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 5g.',
    'รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 15g.',
    'พัฟฟองน้ำเจ้านาง - Chaonang Puff',
    'แป้งฝุ่นเจ้านาง (6.5ก.) - Chaonang Diamond Translucent Powder 6.5g.',
    'แป้งเจ้านาง 10ก. (แพคเกจใหม่) - Chaonang Perfect Bright UV 2-way Powder Foundation 10g.',
    'คุชชั่นเจ้านาง - Chaonang Glowy Cushion SPF30 PA+++ 15g.',
    'ดินสอเขียนคิ้วเจ้านาง - Chaonang Slim Waterproof Eyebrow'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2025 and match the specified products
is_2025 = (shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2025)
matches_products_2025_old = shopee2['ชื่อสินค้า'].isin(products_to_categorize_as_old_2025)

# Apply the 'old' categorization to the 'group' column for matching rows
shopee2.loc[is_2025 & matches_products_2025_old, 'group'] = 'old'

print("Updated 'group' column for specified 2025 products (old category):")
print(shopee2['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2025 products (old category):
# group
# old       53794
# newset    19167
# new       13356
# oldset     6925
# None       2238
# Name: count, dtype: int64

# %%
products_to_categorize_as_new_2025 = [
    'กันแดดเจ้านาง (30ก.) - Chaonang Milky Sunscreen SPF50+ PA+++ 30g.',
    'รองพื้นเจ้านางผิวกระจก แบบซอง (5ก.) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g.',
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง (6ซอง/กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (6pcs/box)',
    'ลิปบาล์มเจ้านาง - Chaonang Glowy Tint Balm SPF15 PA+++'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2025 and match the specified new products
is_2025 = (shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2025)
matches_products_2025_new = shopee2['ชื่อสินค้า'].isin(products_to_categorize_as_new_2025)

# Apply the 'new' categorization to the 'group' column for matching rows
shopee2.loc[is_2025 & matches_products_2025_new, 'group'] = 'new'

print("Updated 'group' column for specified 2025 products (new category):")
print(shopee2['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2025 products (new category):
# group
# old       53794
# newset    19167
# new       13356
# oldset     6925
# None       2238
# Name: count, dtype: int64

# %%
newset_products_2025 = [
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง (12 กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (12 box)',
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง (24 กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (24 box)',
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง (48 กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (48 box)',
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง (6กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (6 box)',
    '[1แถม1] ดินสอเขียนคิ้วเจ้านาง (แบบซอง) - Chaonang Slim Waterproof Eyebrow',
    '[Chaonang set] แป้งพัฟเจ้านาง + พัฟฟองน้ำซอง',
    '[Chaonang set] แป้งพัฟเจ้านาง + รองพื้นซองยกกล่อง',
    '[Double Day 1-7 ก.พ.] คุชชั่น + รองพื้นหลอด',
    '[Double Day 1-7 ก.พ.] รองพื้นหลอด + ดินสอเขียนคิ้ว(แบบกล่อง)',
    '[Double Day 2-8 มี.ค.] คุชชั่น + อายไลเนอร์(แบบกล่อง)',
    '[Double Day 2-8 มี.ค.] แป้งพัฟ + รองพื้นซองสูตรเดิม + ดินสอเขียนคิ้ว(แบบกล่อง)',
    '[Double Day 2-8 มี.ค.] แป้งพัฟเจ้านาง + รองพื้น glass skin 2 ซอง',
    '[Flash Sale] ดินสอเขียนคิ้วเจ้านาง(กล่อง) - Chaonang Slim Waterproof Eyebrow EXP 11/8/2025',
    '[Mid Month 11-17 มี.ค.] แป้งฝุ่นเจ้านาง + รองพื้นซองสูตรเดิมยกกล่อง1 กล่อง',
    '[Mid Month 11-17 มี.ค.] แป้งพัฟเจ้านาง + รองพื้น glass skin 1 กล่อง',
    '[Mid Month 11-17ก.พ.] คุชชั่น + ดินสอเขียนคิ้ว(แบบกล่อง)',
    '[Mid Month 11-17ก.พ.] ดินสอเขียนคิ้ว(แบบกล่อง) + อายไลเนอร์(แบบกล่อง)',
    '[Pay Day 25-31 มี.ค.] ลิปบาล์มเจ้านาง + แป้งพัฟเจ้านาง',
    '[เซตผิวสวยท้าแดด] คุชชั่นเจ้านาง (15ก.)  + กันแดดเจ้านาง (30ก.)',
    '[เซตผิวสวยท้าแดด] แป้งพัฟเจ้านาง (10ก.) + กันแดดเจ้านาง (30ก.)',
    '[เซตผิวสวยท้าแดด] รองพื้นเจ้านาง (15ก.) + กันแดดเจ้านาง (30ก.)',
    '[เซทบำรุงผิว] ลิปบาล์ม + กันแดดเจ้านาง',
    '[แพ็ค 2 ชิ้น สุดคุ้ม] กันแดดเจ้านาง (30ก.) - Chaonang Milky Sunscreen SPF50+ PA+++ 30g.',
    '[แพ็ค 2 ชิ้น สุดคุ้ม] แป้งฝุ่นเจ้านาง (6.5ก.) - Chaonang Diamond Translucent Powder 6.5g.',
    '[แพ็ค 2 ตลับ สุดคุ้ม] คุชชั่นเจ้านาง (15ก.) - Chaonang Glowy Cushion SPF30 PA+++ 15g.',
    '[แพ็ค 2 ตลับ สุดคุ้ม] แป้งพัฟเจ้านาง (10ก.) - Chaonang Perfect Bright UV 2-way Powder Foundation 10g.',
    '[แพ็ค 2 หลอด สุดคุ้ม] รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 5g.',
    '[แพ็ค 3 ชิ้น คุ้มสุดๆ] แป้งฝุ่นเจ้านาง (6.5ก.) - Chaonang Diamond Translucent Powder 6.5g.',
    '[แพ็ค 3 ตลับ คุ้มสุดๆ] แป้งพัฟเจ้านาง (10ก.) - Chaonang Perfect Bright UV 2-way Powder Foundation 10g.',
    '[แพ็ค 3 หลอด สุดคุ้ม] รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 15g.',
    '[แพ็คสุดคุ้ม 2 Box ] รองพื้นซอง(6pcs/Box)-Chaonang Radiance Skin Foundation SPF30 PA+++',
    '[แพ็คสุดคุ้ม 3 ตลับ] คุชชั่นเจ้านาง - Chaonang glowy cushion spf30 pa+++',
    '[ใหม่] แป้งฝุ่นเจ้านาง + รองพื้น glass skin 1 กล่อง',
    '[ใหม่] แป้งฝั่่นเจ้านาง + รองพื้น glass skin 2 ซอง',
    '[ใหม่] แป้งพัฟเจ้านาง + รองพื้น glass skin 2 ซอง',
    '[ใหม่] ลิปบาล์มเจ้านาง + คุชชั่นเจ้านาง',
    '[ใหม่] ลิปบาล์มเจ้านาง + แป้งฝุ่นเจ้านาง',
    '[ใหม่] ลิปบาล์มเจ้านาง + แป้งพัฟเจ้านาง',
    '[ใหม่] ลิปบาล์มเจ้านาง + รองพื้นหลอดเจ้านาง'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2025 and match the specified newset products
is_2025 = (shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2025)
matches_products_2025_newset = shopee2['ชื่อสินค้า'].isin(newset_products_2025)

# Apply the 'newset' categorization to the 'group' column for matching rows
shopee2.loc[is_2025 & matches_products_2025_newset, 'group'] = 'newset'

print("Updated 'group' column for specified 2025 products (newset category):")
print(shopee2['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2025 products (newset category):
# group
# old       53794
# newset    19167
# new       13356
# oldset     6925
# None       2238
# Name: count, dtype: int64

# %%
products_to_categorize_as_oldset_2025 = [
    '[ใหม่] แป้งฝุ่นเจ้านาง + รองพื้น glass skin 2 ซอง',
    '[เซตผิวสวยสุดคุ้ม] แป้งพัฟเจ้านาง (10ก.) + รองพื้นหลอดเจ้านาง (15ก.)',
    '[เซตสวยครบจบที่เดียว] คุชชั่นเจ้านาง (15ก.) + แป้งฝุ่นเจ้านาง (6.5ก.)',
    '[เซตสวยคุ้ม]  แป้งพัฟเจ้านาง (10ก.) + รองพื้นหลอดเจ้านาง (15ก.)',
    '[PayDay ] คุชชั่น (15g) +แป้งฝุ่น (6.5g)',
    '[PayDay ] แป้งพัฟ + รองพื้นซองยกกล่อง',
    '[PayDay ] แป้งพัฟ + ลิปจุ่มEXP.12/6/2025',
    '[Special Set] แป้งพัฟ + รองพื้นหลอด + ลิปจุ่ม03 EXP.12/6/2025',
    '[Special Set] แป้งพัฟ + รองพื้นหลอด + ลิปจุ่ม03 EXP.12/6/2025',
    '[Mid Month 11-17 มี.ค.] แป้งพัฟเจ้านาง + แป้งฝุ่นเจ้านาง',
    '[Mid Month 11-17ก.พ.] แป้งพัฟเจ้านาง + แป้งฝุ่นเจ้านาง',
    '[PayDay ] คุชชั่น (15g) +แป้งฝุ่น (6.5g)',
    '[Pay Day 20-28 ก.พ.] แป้งฝุ่นเจ้านาง (6.5ก.) + รองพื้นหลอดเจ้านาง (15ก.)',
    '[Pay Day 20-28 ก.พ.] แป้งพัฟ + ดินสอเขียนคิ้ว(แบบกล่อง)',
    '[Pay Day 25-30 เม.ย.] คุชชั่น+แป้งพัฟ',
    '[Pay Day 25-31 มี.ค.] คุชชั่น + รองพื้นหลอด',
    '[Pay Day 25-31 มี.ค.] คุชชั่น+แป้งพัฟ',
    '[Flash Sale] ดินสอเขียนคิ้วเจ้านาง(ซอง) - Chaonang Slim Waterproof Eyebrow',
    '[Hello 2025 | 4-10 ม.ค.] คุชชั่นเจ้านาง +แป้งพัฟเจ้านาง',
    '[Hello 2025 | 4-10 ม.ค.] แป้งพัฟเจ้านาง + แป้งฝุ่นเจ้านาง',
    '[Hello 2025 | 4-10 ม.ค.] รองพื้นหลอด + ลิปจุ่ม EXP.13/6/2025',
    '[Hello 2025] คุชชั่นเจ้านาง +แป้งพัฟเจ้านาง',
    '[Mid Month 11-17 ม.ค.]  คุชชั่น + ลิปจุ่ม05 EXP.13/6/2025',
    '[Mid Month 11-17 ม.ค.] แป้งฝุ่นเจ้านาง (6.5ก.) + รองพื้นหลอดเจ้านาง (15ก.)',
    '[Mid Month 11-17 ม.ค.] แป้งพัฟเจ้านาง (10ก.) + รองพื้นหลอดเจ้านาง (15ก.)',
    '[Double Day 1-7 ก.พ.] คุชชั่น+แป้งฝุ่น'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2025 and match the specified products
is_2025 = (shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2025)
matches_products_2025_oldset = shopee2['ชื่อสินค้า'].isin(products_to_categorize_as_oldset_2025)

# Apply the 'oldset' categorization to the 'group' column for matching rows
shopee2.loc[is_2025 & matches_products_2025_oldset, 'group'] = 'oldset'

print("Updated 'group' column for specified 2025 products (oldset category):")
print(shopee2['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2025 products (oldset category):
# group
# old       53794
# newset    19167
# new       13356
# oldset     6925
# None       2238
# Name: count, dtype: int64

# %%
products_to_categorize_as_old_2026 = [
    'กันแดดเจ้านาง (30ก.) - Chaonang Milky Sunscreen SPF50+ PA+++ 30g.',
    'แป้งเจ้านาง 10ก. (แพคเกจใหม่) - Chaonang Perfect Bright UV 2-way Powder Foundation 10g.',
    'รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 15g.',
    'รองพื้นเจ้านาง แบบซอง (5ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 5g.',
    'รองพื้นเจ้านางแบบกล่อง (1 กล่อง) - Chaonang Radiance Skin Foundation SPF30 PA+++ (1 Box)',
    'Glass skin รองพื้นเจ้านางผิวกระจกแบบซอง (5ก.) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g.',
    '[หมดอายุ 12/2026] คุชชั่นเจ้านาง - Chaonang Glowy Cushion SPF30 PA+++ 15g.'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2026 and match the specified products
is_2026 = (shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2026)
matches_products_2026_old = shopee2['ชื่อสินค้า'].isin(products_to_categorize_as_old_2026)

# Apply the 'old' categorization to the 'group' column for matching rows
shopee2.loc[is_2026 & matches_products_2026_old, 'group'] = 'old'

print("Updated 'group' column for specified 2026 products (old category):")
print(shopee2['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2026 products (old category):
# group
# old       53794
# newset    19167
# new       13356
# oldset     6925
# None       2238
# Name: count, dtype: int64

# %%
products_to_categorize_as_new_2026 = [
    'Care Skin รองพื้นเจ้านางแคร์สกิน (5ก.) - Chaonang Care Skin Foundation SPF30 PA+++ 5g.',
    'Airy คุชชั่นเจ้านางแบบกล่อง (1กล่อง) - Chaonang Airy Cushion SPF35 PA+++ (1BOX)',
    'Airy คุชชั่นเจ้านางแบบซอง(5ก.) บางเบา ปกปิด คุมมัน - Chaonang Airy Cushion SPF35 PA+++ (5g.)',
    'Care Skin รองพื้นเจ้านางแคร์สกิน (1กล่อง) - Chaonang Care Skin Foundation SPF30 PA+++ (1BOX)',
    'Glass skin รองพื้นเจ้านางผิวกระจกแบบกล่อง(1กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g.(1 Box)',
    'Glowy Tint รองพื้นเจ้านางโกลว์วี่ทินท์ (1กล่อง) - Chaonang Glowy Tint Foundation SPF30 PA+++ 5g. (1BOX)',
    'Glowy Tint รองพื้นเจ้านางโกลว์วี่ทินท์ (5ก.) - Chaonang Glowy Tint Foundation SPF30 PA+++ 5g.',
    'ลิปเจ้านาง Glowy Bloom - Chaonang Glowy Bloom Liquid Lip 2.5g.',
    'แป้งฝุ่นเจ้านาง Glow Filter - Chaonang Glow Filter Translucent Powder 6.5g.',
    'แป้งพัฟเจ้านาง Glow Skin - Chaonang Glow Skin Powder Foundation 10g.',
    'แป้งพัฟเจ้านาง To go ขนาด 5g. - Chaonang Perfect Bright UV 2 Way Powder Foundation To go',
    'คอนซีลเลอร์เจ้านาง - Chaonang Flawless Skin Concealer 2g.',
    'คอนซีลเลอร์เจ้านาง (1กล่อง) - Chaonang Flawless Skin Concealer 2g.',
    'บลัชออนเจ้านาง เจ้านาง ซอฟต์บลัช พาวเดอร์ - Chaonang Soft Blush Powder'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2026 and match the specified products
is_2026 = (shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2026)
matches_products_2026_new = shopee2['ชื่อสินค้า'].isin(products_to_categorize_as_new_2026)

# Apply the 'new' categorization to the 'group' column for matching rows
shopee2.loc[is_2026 & matches_products_2026_new, 'group'] = 'new'

print("Updated 'group' column for specified 2026 products (new category):")
print(shopee2['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2026 products (new category):
# group
# old       53794
# newset    19167
# new       13356
# oldset     6925
# None       2238
# Name: count, dtype: int64

# %%
newset_products_2026 = [
    '[1 แถม 1] บลัชออนเจ้านาง เจ้านาง ซอฟต์บลัช พาวเดอร์ - Chaonang Soft Blush Powder',
    '[1แถม1] ลิปเจ้านาง Glowy Bloom - Chaonang Glowy Bloom Liquid Lip 2.5g.',
    '[แพ็ค 2 ตลับ สุดคุ้ม] แป้งพัฟเจ้านาง To go ขนาด 5g. - Chaonang Perfect Bright UV 2 Way Powder Foundation To go',
    '[แพ็ค 2 ตลับ] แป้งฝุ่นเจ้านาง Glow Filter - Chaonang Glow Filter Translucent Powder 6.5g.',
    '[แพ็ค 2 ตลับ] แป้งพัฟเจ้านาง Glow Skin  - Chaonang Glow Skin Foundation 10g.',
    '[แพ็ค 3 ตลับ สุดคุ้ม] แป้งพัฟเจ้านาง To go ขนาด 5g. - Chaonang Perfect Bright UV 2 Way Powder Foundation To go',
    '[แพ็ค 3 ตลับ] แป้งฝุ่นเจ้านาง Glow Filter - Chaonang Glow Filter Translucent Powder 6.5g.',
    '[แพ็ค 3 ตลับ] แป้งพัฟเจ้านาง Glow Skin - Chaonang Glow Skin Powder Foundation 10g.',
    '[แพ็ค 6 ตลับ] แป้งพัฟเจ้านาง Glow Skin - Chaonang Glow Skin Powder Foundation 10g.',
    '[แพ็คสุดคุ้ม 2 Box ] Care skin รองพื้นเจ้านางแคร์สกิน - Chaonang Care Skin Foundation SPF30 PA+++',
    '[แพ็คสุดคุ้ม 2 Box ] Glowy Tint รองพื้นเจ้านางโกลว์วี่ทินท์ - Chaonang Glowy Tint Foundation SPF30 PA+++',
    '[แพ็คสุดคุ้ม 2 Box] Airy คุชชั่นเจ้านางแบบซอง - Chaonang Airy Cushion SPF35 PA+++',
    '[แพ็คสุดคุ้ม 2 Box] Glass skin รองพื้นเจ้านางผิวกระจกแบบกล่อง - Chaonang Glass Skin Foundation SPF30 PA+++',
    '[แพ็คสุดคุ้ม 3 Box ] Care skin รองพื้นเจ้านางแคร์สกิน - Chaonang Care Skin Foundation SPF30 PA+++',
    '[หมดอายุ 12/2026] คุชชั่นเจ้านาง + Airy คุชชั่นเจ้านาง 1 ซอง',
    'Airy คุชชั่นซองเจ้านาง 3 ซอง + คอนซีลเลอร์เจ้านาง 1 ซอง',
    'คอนซีลเลอร์เจ้านาง + แป้งพัฟเจ้านาง',
    'คอนซีลเลอร์เจ้านาง + แป้งพัฟเจ้านาง Glow skin',
    'คอนซีลเลอร์เจ้านาง + รองพื้นหลอดเจ้านาง',
    'แป้งฝุ่นเจ้านาง Glow filter +  Airy คุชชั่นซองเจ้านาง 2 ซอง',
    'แป้งฝุ่นเจ้านาง Glow Filter + แป้งพัฟเจ้านาง',
    'แป้งฝุ่นเจ้านาง Glow filter + รองพื้นซองเจ้านางสูตร Glass skin 2 ซอง',
    'แป้งฝุ่นเจ้านาง Glow filter + รองพื้นซองเจ้านางสูตร Radiance 2 ซอง',
    'แป้งฝุ่นเจ้านาง Glow Filter + รองพื้นหลอดเจ้านาง',
    'แป้งพัฟเจ้านาง (10g.) + แป้งพัฟเจ้านาง To go (5g.)',
    'แป้งพัฟเจ้านาง +  Airy คุชชั่นซองเจ้านาง 2 ซอง',
    'แป้งพัฟเจ้านาง + Airy คุชชั่นซองเจ้านาง 1 box',
    'แป้งพัฟเจ้านาง + รองพื้นเจ้านางสูตร glass skin 2 ซอง',
    'แป้งพัฟเจ้านาง Glow skin + คุชชั่นเจ้านาง [คุชชั่นหมดอายุ 12/2026]',
    'แป้งพัฟเจ้านาง Glow skin + แป้งฝุ่นเจ้านาง Glow Filter',
    'แป้งพัฟเจ้านาง Glow skin + แป้งพัฟเจ้านาง To go',
    'แป้งพัฟเจ้านาง Glow skin + รองพื้นหลอดเจ้านาง',
    'แป้งพัฟเจ้านาง To go + Airy คุชชั่นซองเจ้านาง 1 ซอง',
    'แป้งพัฟเจ้านาง To go + รองพื้นซองเจ้านาง สูตร Care Skin 1 ซอง',
    'แป้งพัฟเจ้านาง To go + รองพื้นซองเจ้านาง สูตร Glass Skin 1 ซอง',
    'แป้งพัฟเจ้านาง To go + รองพื้นซองเจ้านาง สูตร Glowy Tint 1 ซอง',
    'แป้งพัฟเจ้านาง To go + รองพื้นซองเจ้านาง สูตร Radiance 1 ซอง',
    'รองพื้นเจ้านางสูตร Glass skin 3 ซอง + คอนซีลเลอร์เจ้านาง 1 ซอง',
    'รองพื้นซองเจ้านาง Care skin 2 ซอง + แป้งพัฟเจ้านาง To go',
    'รองพื้นซองเจ้านาง Care skin 3 ซอง + แป้งพัฟเจ้านาง Glow Skin',
    'ลิปเจ้านาง Glowy Bloom + บลัชออนเจ้านาง Soft Blush Powder',
    'แป้งพัฟเจ้านาง+รองพื้นซองเจ้านางสูตร glass skin ยกกล่อง',
    'Glass skin รองพื้นเจ้านางผิวกระจกแบบกล่อง (6กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (6 box)'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2026 and match the specified products
is_2026 = (shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2026)
matches_products_2026_newset = shopee2['ชื่อสินค้า'].isin(newset_products_2026)

# Apply the 'newset' categorization to the 'group' column for matching rows
shopee2.loc[is_2026 & matches_products_2026_newset, 'group'] = 'newset'

print("Updated 'group' column for specified 2026 products (newset category):")
print(shopee2['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2026 products (newset category):
# group
# old       53794
# newset    19167
# new       13356
# oldset     6925
# None       2238
# Name: count, dtype: int64

# %%
products_to_categorize_as_oldset_2026 = [
    '[เซตผิวสวยท้าแดด] คุชชั่นเจ้านาง (15ก.)  + กันแดดเจ้านาง (30ก.) [คุชชั่นหมดอายุ 12/2026]',
    '[เซตผิวสวยท้าแดด] แป้งพัฟเจ้านาง (10ก.) + กันแดดเจ้านาง (30ก.)',
    '[เซตผิวสวยท้าแดด] รองพื้นเจ้านาง (15ก.) + กันแดดเจ้านาง (30ก.)',
    '[เซตผิวสวยสุดคุ้ม] แป้งพัฟเจ้านาง (10ก.) + รองพื้นหลอดเจ้านาง (15ก.)',
    '[แพ็ค 2 ชิ้น สุดคุ้ม] กันแดดเจ้านาง (30ก.) - Chaonang Milky Sunscreen SPF50+ PA+++ 30g.',
    '[แพ็ค 2 ตลับ สุดคุ้ม] แป้งพัฟเจ้านาง (10ก.) - Chaonang Perfect Bright UV 2-way Powder Foundation10g.',
    '[แพ็ค 2 หลอด สุดคุ้ม] รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 15g.',
    '[แพ็ค 3 ตลับ] แป้งพัฟเจ้านาง (10ก.) - Chaonang Perfect Bright UV 2-way Powder Foundation10g.',
    '[แพ็ค 3 หลอด สุดคุ้ม] รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 15g.',
    '[แพ็คสุดคุ้ม 2 Box ] รองพื้นซองเจ้านางสูตร Radiance - Chaonang Radiance Skin Foundation SPF30 PA+++ [หมดอายุ 12/2026]',
    '[แพ็ค 2 ตลับ สุดคุ้ม] คุชชั่นเจ้านาง (15ก.) - Chaonang Glowy Cushion SPF30 PA+++ 15g. [หมดอายุ 12/2026]',
    '[แพ็คสุดคุ้ม 3 ตลับ] คุชชั่นเจ้านาง - Chaonang glowy cushion spf30 pa+++ [หมดอายุ 12/2026]',
    'คุชชั่นเจ้านาง - Chaonang Glowy Cushion SPF30 PA+++ 15g.',
    'คุชชั่นเจ้านาง + แป้งพัฟเจ้านาง [คุชชั่นหมดอายุ 12/2026]'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
shopee2['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(shopee2['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2026 and match the specified products
is_2026 = (shopee2['วันที่ทำการสั่งซื้อ'].dt.year == 2026)
matches_products_2026_oldset = shopee2['ชื่อสินค้า'].isin(products_to_categorize_as_oldset_2026)

# Apply the 'oldset' categorization to the 'group' column for matching rows
shopee2.loc[is_2026 & matches_products_2026_oldset, 'group'] = 'oldset'

print("Updated 'group' column for specified 2026 products (oldset category):")
print(shopee2['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2026 products (oldset category):
# group
# old       53794
# newset    19167
# new       13356
# oldset     6925
# None       2238
# Name: count, dtype: int64

# %%
shopee2
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#       เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
import re

# Define the keyword to search for, escaping special characters
keyword_to_search = re.escape('(ของแถม)')

# Filter the DataFrame to find rows where 'ชื่อสินค้า' contains the keyword
matching_rows_count = shopee2['ชื่อสินค้า'].str.contains(keyword_to_search, na=False, regex=True).sum()

print(f"จำนวนแถวในคอลัมน์ 'ชื่อสินค้า' ที่มีคำว่า '(ของแถม)': {matching_rows_count} แถว")
# Out:
# จำนวนแถวในคอลัมน์ 'ชื่อสินค้า' ที่มีคำว่า '(ของแถม)': 0 แถว

# %%
import re

# Define the keyword to search for, escaping special characters
keyword_to_search = re.escape('(ของแถม)')

# Create a boolean mask for rows that contain the keyword
mask_to_drop = shopee2['ชื่อสินค้า'].str.contains(keyword_to_search, na=False, regex=True)

# Drop the rows that match the mask
shopee2 = shopee2[~mask_to_drop]

print(f"DataFrame 'shopee2' หลังจากลบแถวที่มี '(ของแถม)': {shopee2.shape[0]} แถว และ {shopee2.shape[1]} คอลัมน์")
# Out:
# DataFrame 'shopee2' หลังจากลบแถวที่มี '(ของแถม)': 95480 แถว และ 35 คอลัมน์

# %%
shopee2
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#       เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
shopee2
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#       เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
discount
# Out:
#       หมายเลขคำสั่งซื้อรวม  ยอดขายรวม  ส่วนลดรวม  ราคาลูกค้าจ่าย    Disรวม%
# 0           240102SP39BMES        374         75             299  20.053476
# 1           240102SRPHXTVH        380        100             280  26.315789
# 2           240102SVCS34FQ        564          0             564   0.000000
# 3           240102SVN27JNU        380          0             380   0.000000
# 4           240102T3HW191Y        175        100              75  57.142857
# ...                    ...        ...        ...             ...        ...
# 80710       260401KMT1TK9D        349         85             264  24.355301
# 80711       260401KMTCB3NA        209         83             126  39.712919
# 80712       260401KMUCRTYX        118         21              97  17.796610
# 80713       260401KMX4FVBY        349         70             279  20.057307
# 80714       260401KN1TTP9K        159         62              97  38.993711
#
# [80715 rows x 5 columns]

# %%
# =========================================
# COPY DATA
# =========================================

item_df = shopee2.copy()
order_df = discount.copy()

# =========================================
# CLEAN ORDER ID
# =========================================

item_df['หมายเลขคำสั่งซื้อ'] = (
    item_df['หมายเลขคำสั่งซื้อ']
    .astype(str)
    .str.strip()
)

order_df['หมายเลขคำสั่งซื้อรวม'] = (
    order_df['หมายเลขคำสั่งซื้อรวม']
    .astype(str)
    .str.strip()
)

# =========================================
# MERGE 2 TABLES
# =========================================

merged_df = pd.merge(
    item_df,
    order_df[
        [
            'หมายเลขคำสั่งซื้อรวม',
            'ยอดขายรวม',
            'ส่วนลดรวม',
            'ราคาลูกค้าจ่าย',
            'Disรวม%'
        ]
    ],
    left_on='หมายเลขคำสั่งซื้อ',
    right_on='หมายเลขคำสั่งซื้อรวม',
    how='left'
)

# =========================================
# OPTIONAL : DROP DUPLICATE KEY COLUMN
# =========================================

merged_df = merged_df.drop(
    columns=['หมายเลขคำสั่งซื้อรวม']
)

# =========================================
# CHECK RESULT
# =========================================

print(merged_df.shape)

display(merged_df.head())

# =========================================
# CHECK NULL
# =========================================

print(
    merged_df[
        ['ยอดขายรวม', 'ส่วนลดรวม']
    ].isnull().sum()
)

# =========================================
# EXPORT FILE
# =========================================

merged_df.to_excel(
    'merged_shopee_data.xlsx',
    index=False
)

print("Merge Complete")
# Out:
# (95480, 39)
#   หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0    240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1    240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2    240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3    240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4    240102SRPHXTVH                          NaN 2024-01-02 16:05:00
#
#   เวลาการชำระสินค้า    ช่องทางการชำระเงิน ช่องทางการชำระเงิน_(รายละเอียด)  \
# 0  2024-01-03 12:44        Mobile Banking                             NaN
# 1  2024-01-03 12:44        Mobile Banking                             NaN
# 2  2024-01-02 23:26  บัตรเครดิต/บัตรเดบิต                             NaN
# 3  2024-01-02 23:26  บัตรเครดิต/บัตรเดบิต                             NaN
# 4  2024-01-02 16:35       เก็บเงินปลายทาง                             NaN
#
#               แผนการผ่อนชำระ ค่าธรรมเนียม_(%)  \
# ...

# %% [markdown]
# ### Merge

# %%
file_path102 = '/content/drive/MyDrive/intern CHN/merged_shopee_data_Final.xlsx'

# %%
merged_df1 = pd.read_excel(file_path102)

# %%
merged_df1
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#         เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
merged_df1 = merged_df1.drop(columns=['duration'])
print("The 'duration' column has been dropped from the DataFrame.")
# Out:
# The 'duration' column has been dropped from the DataFrame.

# %%
merged_df1['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(merged_df1['วันที่ทำการสั่งซื้อ'], errors='coerce')
merged_df1['เวลาการชำระสินค้า'] = pd.to_datetime(merged_df1['เวลาการชำระสินค้า'], errors='coerce')
merged_df1['Duration'] = merged_df1['เวลาการชำระสินค้า'] - merged_df1['วันที่ทำการสั่งซื้อ']
print("The 'Duration' column has been created in merged_df1.")
print(merged_df1[['วันที่ทำการสั่งซื้อ', 'เวลาการชำระสินค้า', 'Duration']].head())
# Out:
# The 'Duration' column has been created in merged_df1.
#   วันที่ทำการสั่งซื้อ   เวลาการชำระสินค้า        Duration
# 0 2024-01-03 12:44:00 2024-01-03 12:44:00 0 days 00:00:00
# 1 2024-01-03 12:44:00 2024-01-03 12:44:00 0 days 00:00:00
# 2 2024-01-02 23:26:00 2024-01-02 23:26:00 0 days 00:00:00
# 3 2024-01-02 23:26:00 2024-01-02 23:26:00 0 days 00:00:00
# 4 2024-01-02 16:05:00 2024-01-02 16:35:00 0 days 00:30:00

# %%
merged_df1 = merged_df1.drop(columns=['Duration'])
print("The 'duration' column has been dropped from the DataFrame.")
# Out:
# The 'duration' column has been dropped from the DataFrame.

# %%
merged_df1['Duration'] = None

# %%
merged_df1['Duration'] = (merged_df1['เวลาการชำระสินค้า'] - merged_df1['วันที่ทำการสั่งซื้อ'])

# %%
merged_df1
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#         เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
merged_df[merged_df['หมายเลขคำสั่งซื้อ']=='24010401QA9RHK']
# Out:
#   หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 7    24010401QA9RHK                          NaN 2024-01-04 00:24:00
# 8    24010401QA9RHK                          NaN 2024-01-04 00:24:00
#
#     เวลาการชำระสินค้า ช่องทางการชำระเงิน ช่องทางการชำระเงิน_(รายละเอียด)  \
# 7 2024-01-04 00:24:00          SPayLater      Shopee Credit Down Payment
# 8 2024-01-04 00:24:00          SPayLater      Shopee Credit Down Payment
#
#      แผนการผ่อนชำระ ค่าธรรมเนียม_(%)  \
# 7  Shopee Credit x5            3.21%
# 8  Shopee Credit x5            3.21%
#
#                                    ตัวเลือกการจัดส่ง *หมายเลขติดตามพัสดุ  ...  \
# 7  Standard Delivery - ส่งธรรมดาในประเทศ-J&T Express        623406712600  ...
# 8  Standard Delivery - ส่งธรรมดาในประเทศ-J&T Express        623406712600  ...
#
#   ประเทศ               จังหวัด     เขต/อำเภอ เวลาที่ทำการสั่งซื้อสำเร็จ  \
# 7     TH  จังหวัดกรุงเทพมหานคร  เขตบางคอแหลม           2024-01-05 19:22
# ...

# %%
import pandas as pd

# Define the list of products to be categorized as 'newset' for 2025
newset_products_from_user_2025 = [
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง (ยก6กล่อง) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. (6 box)',
    '(สูตรใหม่) รองพื้นเจ้านางผิวกระจก แบบซอง (5ก.) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. ( เครื่องสำอาง ผู้หญิง )',
    '[ใหม่] แป้งพัฟเจ้านาง + รองพื้น glass skin 1 กล่อง'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
merged_df['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(merged_df['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2025 and match the specified products
is_2025 = (merged_df['วันที่ทำการสั่งซื้อ'].dt.year == 2025)
matches_products_from_user_2025 = merged_df['ชื่อสินค้า'].isin(newset_products_from_user_2025)

# Apply the 'newset' categorization to the 'group' column for matching rows
merged_df.loc[is_2025 & matches_products_from_user_2025, 'group'] = 'newset'

print("Updated 'group' column for specified 2025 products (newset category):")
print(merged_df['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2025 products (newset category):
# group
# old       53917
# newset    19167
# new       13356
# oldset     9040
# Name: count, dtype: int64

# %%
products_to_categorize_as_oldset_2025_user = [
    '[Pay Day 20-28 ก.พ.] คุชชั่น+แป้งพัฟ',
    '[Special Set] แป้งพัฟ + รองพื้นหลอด + ลิปจุ่ม EXP.12/6/2025',
    '[แพ็ค 2 หลอด สุดคุ้ม] รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 15g.',
    '[แพ็คสุดคุ้ม 2 Box ] รองพื้นซองเจ้านางสูตร Radiance - Chaonang Radiance Skin Foundation SPF30 PA+++',
    '[หมดอายุ 12/2026] [แพ็ค 2 ตลับ สุดคุ้ม] คุชชั่นเจ้านาง (15ก.) - Chaonang Glowy Cushion SPF30 PA+++ 15g.',
    '[หมดอายุ 12/2026] [แพ็คสุดคุ้ม 3 ตลับ] คุชชั่นเจ้านาง - Chaonang glowy cushion spf30 pa+++'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
merged_df['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(merged_df['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2025 and match the specified products
is_2025 = (merged_df['วันที่ทำการสั่งซื้อ'].dt.year == 2025)
matches_products_2025_oldset_user = merged_df['ชื่อสินค้า'].isin(products_to_categorize_as_oldset_2025_user)

# Apply the 'oldset' categorization to the 'group' column for matching rows
merged_df.loc[is_2025 & matches_products_2025_oldset_user, 'group'] = 'oldset'

print("Updated 'group' column for specified 2025 products (oldset category):")
print(merged_df['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2025 products (oldset category):
# group
# old       53917
# newset    19167
# new       13356
# oldset     9040
# Name: count, dtype: int64

# %%
products_to_categorize_as_old_2025 = [
    'ลิปจุ่มเจ้านาง (3ก.) - Chaonang Liquid Lip Chaonang Ultimate Velvet Lip 3g. (หมดอายุ 6/2025)',
    'ลิปจุ่มเจ้านาง (3ก.) - Chaonang Liquid Lip Chaonang Ultimate Velvet Lip 3g. exp.22/5/2025',
    'อายไลเนอร์เจ้านาง -  Chaonang Long-Lating Waterproof Eyeliner',
    'รองพื้นเจ้านางแบบกล่อง (1 กล่อง) - Chaonang Radiance Skin Foundation SPF30 PA+++ (1 Box)',
    'รองพื้นเจ้านางแบบกล่อง (กล่อง/6ซอง) - Chaonang Radiance Skin Foundation SPF30 PA+++',
    'รองพื้นเจ้านาง แบบซอง (5ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 5g.',
    'รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 15g.',
    'พัฟฟองน้ำเจ้านาง - Chaonang Puff',
    'แป้งฝุ่นเจ้านาง (6.5ก.) - Chaonang Diamond Translucent Powder 6.5g.',
    'แป้งเจ้านาง 10ก. (แพคเกจใหม่) - Chaonang Perfect Bright UV 2-way Powder Foundation 10g.',
    'คุชชั่นเจ้านาง - Chaonang Glowy Cushion SPF30 PA+++ 15g.',
    'ดินสอเขียนคิ้วเจ้านาง - Chaonang Slim Waterproof Eyebrow',
    '(หมดอายุ 6/2025) ลิปจุ่มเจ้านาง (3ก.) - Chaonang Liquid Lip Chaonang Ultimate Velvet Lip 3g.',
    'อายไลเนอร์เจ้านาง - Chaonang Long-Lating Waterproof Eyeliner'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
merged_df['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(merged_df['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2025 and match the specified products
is_2025 = (merged_df['วันที่ทำการสั่งซื้อ'].dt.year == 2025)
matches_products_2025_old = merged_df['ชื่อสินค้า'].isin(products_to_categorize_as_old_2025)

# Apply the 'old' categorization to the 'group' column for matching rows
merged_df.loc[is_2025 & matches_products_2025_old, 'group'] = 'old'

# Also explicitly set the following two products to 'old' for 2025
merged_df.loc[is_2025 & (merged_df['ชื่อสินค้า'] == 'ลิปจุ่มเจ้านาง (3ก.) - Chaonang Liquid Lip Chaonang Ultimate Velvet Lip 3g.'), 'group'] = 'old'
merged_df.loc[is_2025 & (merged_df['ชื่อสินค้า'] == 'อายไลเนอร์เจ้านาง - Chaonang Long-Lating Waterproof Eyeliner'), 'group'] = 'old'

print("Updated 'group' column for specified 2025 products (old category):")
print(merged_df['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2025 products (old category):
# group
# old       53917
# newset    19167
# new       13356
# oldset     9040
# Name: count, dtype: int64

# %%
products_to_categorize_as_oldset_2026_user_request = [
    '[แพ็คสุดคุ้ม 2 Box ] รองพื้นซองเจ้านางสูตร Radiance - Chaonang Radiance Skin Foundation SPF30 PA+++',
    '[หมดอายุ 12/2026] [แพ็ค 2 ตลับ สุดคุ้ม] คุชชั่นเจ้านาง (15ก.) - Chaonang Glowy Cushion SPF30 PA+++ 15g.',
    '[หมดอายุ 12/2026] [แพ็คสุดคุ้ม 3 ตลับ] คุชชั่นเจ้านาง - Chaonang glowy cushion spf30 pa+++'
]

# Ensure 'วันที่ทำการสั่งซื้อ' is a datetime object
merged_df['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(merged_df['วันที่ทำการสั่งซื้อ'], errors='coerce')

# Create a mask for rows that are in 2026 and match the specified products
is_2026 = (merged_df['วันที่ทำการสั่งซื้อ'].dt.year == 2026)
matches_products_2026_oldset_user_request = merged_df['ชื่อสินค้า'].isin(products_to_categorize_as_oldset_2026_user_request)

# Apply the 'oldset' categorization to the 'group' column for matching rows
merged_df.loc[is_2026 & matches_products_2026_oldset_user_request, 'group'] = 'oldset'

print("Updated 'group' column for specified 2026 products (oldset category):")
print(merged_df['group'].value_counts(dropna=False))
# Out:
# Updated 'group' column for specified 2026 products (oldset category):
# group
# old       53917
# newset    19167
# new       13356
# oldset     9040
# Name: count, dtype: int64

# %%
print(merged_df.isnull().sum())
# Out:
# หมายเลขคำสั่งซื้อ                                                                                             0
# สถานะการคืนเงินหรือคืนสินค้า                                                                              95232
# วันที่ทำการสั่งซื้อ                                                                                           0
# เวลาการชำระสินค้า                                                                                             0
# ช่องทางการชำระเงิน                                                                                            0
# ช่องทางการชำระเงิน_(รายละเอียด)                                                                           68158
# แผนการผ่อนชำระ                                                                                                0
# ค่าธรรมเนียม_(%)                                                                                              0
# ...

# %%
print(merged_df['group'].isnull().sum())
# Out:
# 0

# %%
print(merged_df[merged_df['group'].isnull()]['ชื่อสินค้า'])
# Out:
# Series([], Name: ชื่อสินค้า, dtype: object)

# %%
# =========================================
# IMPORT LIBRARY
# =========================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# =========================================
# COPY DATA FROM merged_df
# =========================================
df = merged_df.copy()

# =========================================
# CLEANING & DATATYPE
# =========================================

# แปลงวันที่
date_cols = [
    'วันที่ทำการสั่งซื้อ',
    'เวลาการชำระสินค้า',
    'วันที่คาดว่าจะทำการจัดส่งสินค้า',
    'เวลาส่งสินค้า',
    'เวลาที่ทำการสั่งซื้อสำเร็จ'
]

for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# =========================================
# แปลงตัวเลข
# =========================================

num_cols = [
    'ราคาตั้งต้น',
    'ราคาขาย',
    'จำนวน',
    'จำนวนที่ส่งคืน',
    'ยอดชำระเงิน',
    'ส่วนลดจาก_Shopee',
    'โค้ดส่วนลดชำระโดยผู้ขาย',
    'โค้ดส่วนลดชำระโดย_Shopee_(เช่น_โค้ดจากโปรแกรม_ร้านโค้ดคุ้ม,_โค้ดส่วนลด_Shopee,_โค้ดส่วนลด_Shopee_Mall)',
    'ส่วนลดจากการใช้เหรียญ',
    'ค่าคอมมิชชั่น',
    'ราคาสินค้าที่ชำระโดยผู้ซื้อ_(THB)',
    'ค่าบริการ',
    'จำนวนเงินทั้งหมด',
    'ค่าจัดส่งโดยประมาณ',
    'ค่าธรรมเนียม_(%)',
    'ยอดขายรวม',
    'ส่วนลดรวม',
    'ราคาลูกค้าจ่าย',
    'Disรวม%'
]

for col in num_cols:

    df[col] = (
        df[col]
        .astype(str)
        .str.replace(',', '')
        .str.replace('฿', '')
        .str.replace('%', '')
    )

    df[col] = pd.to_numeric(df[col], errors='coerce')

# =========================================
# CREATE DATE COLUMN
# =========================================

df['year'] = df['วันที่ทำการสั่งซื้อ'].dt.year
df['month'] = df['วันที่ทำการสั่งซื้อ'].dt.month
df['month_name'] = df['วันที่ทำการสั่งซื้อ'].dt.month_name()
df['day'] = df['วันที่ทำการสั่งซื้อ'].dt.day
df['weekday'] = df['วันที่ทำการสั่งซื้อ'].dt.day_name()
df['hour'] = df['เวลาการชำระสินค้า'].dt.hour

# =========================================
# SALES COLUMN
# =========================================

# Gross Sales
df['gross_sales'] = (
    df['ราคาขาย']
    * df['จำนวน']
)

# Net Sales
df['net_sales'] = (
    df['จำนวนเงินทั้งหมด'].fillna(0)
    - df['ค่าคอมมิชชั่น'].fillna(0)
    - df['ค่าบริการ'].fillna(0)
)

# =========================================
# RETURN FLAG
# =========================================

df['return_flag'] = np.where(
    df['จำนวนที่ส่งคืน'] > 0,
    1,
    0
)

# =========================================
# PROCESSING DAY
# =========================================

df['processing_day'] = (
    df['เวลาส่งสินค้า']
    - df['เวลาการชำระสินค้า']
).dt.days

# =========================================
# ESTIMATED PROFIT
# =========================================

df['estimated_profit'] = (
    df['จำนวนเงินทั้งหมด']
    - df['ส่วนลดรวม']
    - df['ค่าคอมมิชชั่น']
    - df['ค่าบริการ']
    - df['ค่าจัดส่งโดยประมาณ']
)

# =========================================
# DISCOUNT RATIO
# =========================================

df['discount_ratio'] = (
    df['ส่วนลดรวม']
    / df['ยอดขายรวม']
)

# =========================================
# ORDER LEVEL DATA
# =========================================

order_df = (
    df[
        [
            'หมายเลขคำสั่งซื้อ',
            'ยอดขายรวม',
            'ส่วนลดรวม',
            'ราคาลูกค้าจ่าย',
            'Disรวม%'
        ]
    ]
    .drop_duplicates()
)

# %%
merged_df1
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#         เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
merged_df1.columns
# Out:
# Index(['หมายเลขคำสั่งซื้อ', 'สถานะการคืนเงินหรือคืนสินค้า',
#        'วันที่ทำการสั่งซื้อ', 'เวลาการชำระสินค้า', 'ช่องทางการชำระเงิน',
#        'ช่องทางการชำระเงิน_(รายละเอียด)', 'แผนการผ่อนชำระ', 'ค่าธรรมเนียม_(%)',
#        'ตัวเลือกการจัดส่ง', '*หมายเลขติดตามพัสดุ',
#        'วันที่คาดว่าจะทำการจัดส่งสินค้า', 'เวลาส่งสินค้า', 'ชื่อสินค้า',
#        'เลขอ้างอิง_SKU_(SKU_Reference_No.)', 'ชื่อตัวเลือก', 'ราคาตั้งต้น',
#        'ราคาขาย', 'จำนวน', 'จำนวนที่ส่งคืน', 'ยอดชำระเงิน', 'ส่วนลดจาก_Shopee',
#        'โค้ดส่วนลดชำระโดยผู้ขาย',
#        'โค้ดส่วนลดชำระโดย_Shopee_(เช่น_โค้ดจากโปรแกรม_ร้านโค้ดคุ้ม,_โค้ดส่วนลด_Shopee,_โค้ดส่วนลด_Shopee_Mall)',
#        'ส่วนลดจากการใช้เหรียญ', 'ค่าคอมมิชชั่น',
#        'ราคาสินค้าที่ชำระโดยผู้ซื้อ_(THB)', 'ค่าบริการ', 'จำนวนเงินทั้งหมด',
#        'ค่าจัดส่งโดยประมาณ', 'ประเทศ', 'จังหวัด', 'เขต/อำเภอ',
#        'เวลาที่ทำการสั่งซื้อสำเร็จ', 'Mecanic_cam', 'group', 'ยอดขายรวม',
#        'ส่วนลดรวม', 'ราคาลูกค้าจ่าย', 'Disรวม%', 'Duration'],
# ...

# %%
merged_df1['Duration'].max()
# Out:
# Timedelta('1 days 00:00:00')

# %%
merged_df
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 1        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 3        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# ...                 ...                          ...                 ...
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95477    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#         เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
output_path_merged_df = '/content/drive/MyDrive/intern CHN/merged_shopee_data_Final.xlsx'
merged_df.to_excel(output_path_merged_df, index=False)
print(f"DataFrame 'merged_df' ถูกส่งออกไปยัง '{output_path_merged_df}' เรียบร้อยแล้ว")
# Out:
# DataFrame 'merged_df' ถูกส่งออกไปยัง '/content/drive/MyDrive/intern CHN/merged_shopee_data_Final.xlsx' เรียบร้อยแล้ว

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# =========================================
# COPY DATA FROM merged_df
# =========================================
df = merged_df1.copy()

# =========================================
# CLEANING & DATATYPE
# =========================================

# แปลงวันที่
date_cols = [
    'วันที่ทำการสั่งซื้อ',
    'เวลาการชำระสินค้า',
    'วันที่คาดว่าจะทำการจัดส่งสินค้า',
    'เวลาส่งสินค้า',
    'เวลาที่ทำการสั่งซื้อสำเร็จ'
]

for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# =========================================
# แปลงตัวเลข
# =========================================

num_cols = [
    'ราคาตั้งต้น',
    'ราคาขาย',
    'จำนวน',
    'จำนวนที่ส่งคืน',
    'ยอดชำระเงิน',
    'ส่วนลดจาก_Shopee',
    'โค้ดส่วนลดชำระโดยผู้ขาย',
    'โค้ดส่วนลดชำระโดย_Shopee_(เช่น_โค้ดจากโปรแกรม_ร้านโค้ดคุ้ม,_โค้ดส่วนลด_Shopee,_โค้ดส่วนลด_Shopee_Mall)',
    'ส่วนลดจากการใช้เหรียญ',
    'ค่าคอมมิชชั่น',
    'ราคาสินค้าที่ชำระโดยผู้ซื้อ_(THB)',
    'ค่าบริการ',
    'จำนวนเงินทั้งหมด',
    'ค่าจัดส่งโดยประมาณ',
    'ค่าธรรมเนียม_(%)',
    'ยอดขายรวม',
    'ส่วนลดรวม',
    'ราคาลูกค้าจ่าย',
    'Disรวม%'
]

for col in num_cols:

    df[col] = (
        df[col]
        .astype(str)
        .str.replace(',', '')
        .str.replace('฿', '')
        .str.replace('%', '')
    )

    df[col] = pd.to_numeric(df[col], errors='coerce')

# =========================================
# CREATE DATE COLUMN
# =========================================

df['year'] = df['วันที่ทำการสั่งซื้อ'].dt.year
df['month'] = df['วันที่ทำการสั่งซื้อ'].dt.month
df['month_name'] = df['วันที่ทำการสั่งซื้อ'].dt.month_name()
df['day'] = df['วันที่ทำการสั่งซื้อ'].dt.day
df['weekday'] = df['วันที่ทำการสั่งซื้อ'].dt.day_name()
df['hour'] = df['เวลาการชำระสินค้า'].dt.hour

# =========================================
# SALES COLUMN
# =========================================

# Gross Sales
df['gross_sales'] = (
    df['ราคาขาย']
    * df['จำนวน']
)

# Net Sales
df['net_sales'] = (
    df['จำนวนเงินทั้งหมด'].fillna(0)
    - df['ค่าคอมมิชชั่น'].fillna(0)
    - df['ค่าบริการ'].fillna(0)
)

# =========================================
# RETURN FLAG
# =========================================

df['return_flag'] = np.where(
    df['จำนวนที่ส่งคืน'] > 0,
    1,
    0
)

# =========================================
# PROCESSING DAY
# =========================================

df['processing_day'] = (
    df['เวลาส่งสินค้า']
    - df['เวลาการชำระสินค้า']
).dt.days

# =========================================
# ESTIMATED PROFIT
# =========================================

df['estimated_profit'] = (
    df['จำนวนเงินทั้งหมด']
    - df['ส่วนลดรวม']
    - df['ค่าคอมมิชชั่น']
    - df['ค่าบริการ']
    - df['ค่าจัดส่งโดยประมาณ']
)

# =========================================
# DISCOUNT RATIO
# =========================================

df['discount_ratio'] = (
    df['ส่วนลดรวม']
    / df['ยอดขายรวม']
)

# =========================================
# ORDER LEVEL DATA (for potential later use)
# =========================================

order_df = (
    df[
        [
            'หมายเลขคำสั่งซื้อ',
            'ยอดขายรวม',
            'ส่วนลดรวม',
            'ราคาลูกค้าจ่าย',
            'Disรวม%'
        ]
    ]
    .drop_duplicates()
)

# =========================================
# 1. SALES BY GROUP
# =========================================

group_sales = (
    df.groupby('group')['net_sales']
    .sum()
    .sort_values(ascending=False)
)

print(group_sales)

fig, ax = plt.subplots(figsize=(10,5))
bars = group_sales.plot(
    kind='bar',
    ax=ax
)

plt.title('Sales by Group')
plt.ylabel('Net Sales')

# Add numerical labels on top of the bars
ax.bar_label(bars.containers[0], fmt='{:,.0f}')

plt.tight_layout()
plt.show()
# Out:
# group
# old       11507328
# oldset     3854085
# newset     3675665
# new        2569874
# Name: net_sales, dtype: int64

# %%
import matplotlib.pyplot as plt

# =========================================
# 2. SALES BY CAMPAIGN
# =========================================

campaign_sales = (
    df.groupby('Mecanic_cam')['net_sales']
    .agg(['sum', 'mean', 'count'])
    .sort_values(by='sum', ascending=False)
)

print(campaign_sales)

fig, ax = plt.subplots(figsize=(12,5))
bars = campaign_sales['sum'].plot(
    kind='bar',
    ax=ax
)

plt.title('Sales by Campaign')
plt.ylabel('Net Sales')

# Add numerical labels on top of the bars
ax.bar_label(bars.containers[0], fmt='{:,.0f}')

plt.tight_layout()
plt.show()
# Out:
#                   sum        mean  count
# Mecanic_cam
# Normal       21265718  226.636094  93832
# Flash Sale     153755  127.915973   1202
# Pay Day         88934  427.567308    208
# Double Day      50337  378.473684    133
# Hello 2025      32956  428.000000     77
# Mid Month       15252  544.714286     28

# %%
# =========================================
# 3. MONTHLY SALES TREND
# =========================================

monthly_sales = (
    df.groupby(['year', 'month'])['net_sales']
    .sum()
    .reset_index()
)

monthly_sales['year_month'] = (
    monthly_sales['year'].astype(str)
    + '-'
    + monthly_sales['month'].astype(str)
)

plt.figure(figsize=(14,5))

plt.plot(
    monthly_sales['year_month'],
    monthly_sales['net_sales']
)

plt.xticks(rotation=90)

plt.title('Monthly Sales Trend')
plt.ylabel('Net Sales')

plt.show()

# %%
# =========================================
# 4. TOP PRODUCTS
# =========================================

top_products = (
    df.groupby('ชื่อสินค้า')
    .agg({
        'จำนวน':'sum',
        'net_sales':'sum',
        'estimated_profit':'sum'
    })
    .sort_values(by='net_sales', ascending=False)
)

print(top_products.head(20))

top_products.head(20)['net_sales'].plot(
    kind='barh',
    figsize=(10,8)
)

plt.title('Top 20 Products')
plt.xlabel('Net Sales')
plt.show()
# Out:
#                                                     จำนวน  net_sales  \
# ชื่อสินค้า
# แป้งเจ้านาง 10ก. (แพคเกจใหม่) - Chaonang Perfec...  18443    4622848
# รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin ...  12102    1660268
# คุชชั่นเจ้านาง - Chaonang Glowy Cushion SPF30 P...   3925    1363960
# (สูตรใหม่) รองพื้นเจ้านางผิวกระจก แบบซอง (5ก.) ...  16411    1236190
# [แพ็คสุดคุ้ม 2 Box ] รองพื้นซองเจ้านางสูตร Radi...   1249     926962
# แป้งพัฟเจ้านาง To go ขนาด 5g. - Chaonang Perfec...   6911     844150
# รองพื้นเจ้านาง แบบซอง (5ก.) - Chaonang Radiance...  10394     811011
# [แพ็ค 2 หลอด สุดคุ้ม] รองพื้นเจ้านาง (15ก.) - C...   2306     627562
# แป้งเจ้านาง (แพคเกจใหม่) - Chaonang Perfect Bri...   1750     612824
# [แพ็คสุดคุ้ม 2 Box ] รองพื้นซอง(6pcs/Box)-Chaon...    739     525387
# รองพื้นเจ้านางแบบกล่อง (1 กล่อง) - Chaonang Rad...   1427     472315
# คุชชั่นเจ้านาง - Chaonang glowy cushion spf30 p...    959     457233
# ...

# %%
# =========================================
# 5. DISCOUNT ANALYSIS
# =========================================

discount_analysis = (
    df.groupby('ชื่อสินค้า')
    .agg({
        'ส่วนลดรวม':'sum',
        'net_sales':'sum'
    })
)

discount_analysis['discount_ratio'] = (
    discount_analysis['ส่วนลดรวม']
    / discount_analysis['net_sales']
)

print(discount_analysis.head())
# Out:
#                                                     ส่วนลดรวม  net_sales  \
# ชื่อสินค้า
# (MID MONTH SET A) คุชชั่นเจ้านาง คู่กับ ลิปจุ่ม...        619       3547
# (สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง ...       1183      12181
# (สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง ...       4920      15327
# (สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง ...       4280      22422
# (สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง ...          0          0
#
#                                                     discount_ratio
# ชื่อสินค้า
# (MID MONTH SET A) คุชชั่นเจ้านาง คู่กับ ลิปจุ่ม...        0.174514
# (สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง ...        0.097118
# (สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง ...        0.321002
# (สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง ...        0.190884
# (สูตรใหม่) รองพื้นเจ้านางผิวกระจก 5ก. แบบกล่อง ...             NaN

# %%
# =========================================
# 6. AOV มูลค่าสั่งซื้อเฉลี่ย (ค่าเฉลี่ยของเงินที่ลูกค้าจ่ายให้กับร้านค้าของคุณใน การสั่งซื้อ 1 ครั้ง)
# =========================================

AOV = (
    order_df['ราคาลูกค้าจ่าย'].sum()
    / order_df['หมายเลขคำสั่งซื้อ'].nunique()
)

print("AOV =", AOV)
# Out:
# AOV = 217.89591773524128

# %%
# =========================================
# 7. BASKET SIZE
# =========================================

basket_size = (
    df.groupby('หมายเลขคำสั่งซื้อ')['จำนวน']
    .sum()
    .mean()
)

print("Basket Size =", basket_size)
# Out:
# Basket Size = 1.3010840612029981

# %% [markdown]
# # GAP Analysis

# %%
unique_orders = merged_df1.drop_duplicates(subset=['หมายเลขคำสั่งซื้อ'])

# %%
unique_orders['เวลาที่ทำการสั่งซื้อสำเร็จ'] = pd.to_datetime(unique_orders['เวลาที่ทำการสั่งซื้อสำเร็จ'])

# Calculate duration for 'เก็บเงินปลายทาง' transactions
cod_mask = unique_orders['ช่องทางการชำระเงิน'] == 'เก็บเงินปลายทาง'
unique_orders.loc[cod_mask, 'duration'] = unique_orders.loc[cod_mask, 'เวลาที่ทำการสั่งซื้อสำเร็จ'] - unique_orders.loc[cod_mask, 'วันที่ทำการสั่งซื้อ']

# Calculate duration for other payment methods
other_mask = unique_orders['ช่องทางการชำระเงิน'] != 'เก็บเงินปลายทาง'
unique_orders.loc[other_mask, 'duration'] = unique_orders.loc[other_mask, 'เวลาการชำระสินค้า'] - unique_orders.loc[other_mask, 'วันที่ทำการสั่งซื้อ']

display(unique_orders.head())
unique_orders = unique_orders.drop(columns=['Duration'])
# Out:
# /tmp/ipykernel_3675/3827473932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_orders['เวลาที่ทำการสั่งซื้อสำเร็จ'] = pd.to_datetime(unique_orders['เวลาที่ทำการสั่งซื้อสำเร็จ'])
# /tmp/ipykernel_3675/3827473932.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_orders.loc[cod_mask, 'duration'] = unique_orders.loc[cod_mask, 'เวลาที่ทำการสั่งซื้อสำเร็จ'] - unique_orders.loc[cod_mask, 'วันที่ทำการสั่งซื้อ']
# ...

# %%
unique_orders[['duration', 'ช่องทางการชำระเงิน']]
# Out:
#               duration          ช่องทางการชำระเงิน
# 0      0 days 00:00:00              Mobile Banking
# 2      0 days 00:00:00        บัตรเครดิต/บัตรเดบิต
# 4      2 days 08:17:00             เก็บเงินปลายทาง
# 5      2 days 18:03:00             เก็บเงินปลายทาง
# 6      0 days 00:00:00                   SPayLater
# ...                ...                         ...
# 95474 18 days 21:57:00             เก็บเงินปลายทาง
# 95475  0 days 00:00:00                   SPayLater
# 95476  0 days 00:01:00  ShopeePay - ตัดบัญชีธนาคาร
# 95478  0 days 00:00:00                   SPayLater
# 95479  0 days 00:30:00                QR พร้อมเพย์
#
# [80715 rows x 2 columns]

# %%
unique_orders
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 4        240102SRPHXTVH                          NaN 2024-01-02 16:05:00
# 5        240102TCV8869T                          NaN 2024-01-02 22:06:00
# 6        2401040WQKYE7R                          NaN 2024-01-04 08:45:00
# ...                 ...                          ...                 ...
# 95474    260331KAX7SPNF                          NaN 2026-03-31 20:56:00
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#         เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
hh = unique_orders[unique_orders['ช่องทางการชำระเงิน'] != 'เก็บเงินปลายทาง']

# %%
hh
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 0        240103UWX9N588                          NaN 2024-01-03 12:44:00
# 2        240103THAPRG1G                          NaN 2024-01-02 23:26:00
# 6        2401040WQKYE7R                          NaN 2024-01-04 08:45:00
# 7        24010401QA9RHK                          NaN 2024-01-04 00:24:00
# 9        240102SVCS34FQ                          NaN 2024-01-02 17:11:00
# ...                 ...                          ...                 ...
# 95473    260401KKH2HSRN                          NaN 2026-03-31 23:30:00
# 95475    260331JHGT5Q6J                          NaN 2026-03-31 13:21:00
# 95476    260401KMUCRTYX                          NaN 2026-03-31 23:53:00
# 95478    260331JQFA1UTK                          NaN 2026-03-31 15:08:00
# 95479    260331KGWSY0SN                          NaN 2026-03-31 22:43:00
#
#         เวลาการชำระสินค้า          ช่องทางการชำระเงิน  \
# ...

# %%
unique_orders['duration'].max()
# Out:
# Timedelta('26 days 13:12:00')

# %%
unique_orders['duration'].mean()
# Out:
# Timedelta('3 days 05:04:35.186024902')

# %% [markdown]
# เป็นการเก็บเงินแบบปลายทาง
#
# Must do! เจาะดูว่าออเดอร์ไหน ขนส่งไหน

# %%
specific_order = unique_orders[
    (unique_orders['ช่องทางการชำระเงิน'] == 'เก็บเงินปลายทาง') &
    (unique_orders['duration'] >= pd.Timedelta('26 days 13:12:00'))
]
specific_order
# Out:
#       หมายเลขคำสั่งซื้อ สถานะการคืนเงินหรือคืนสินค้า วันที่ทำการสั่งซื้อ  \
# 16305    2501118ME6D7MF                          NaN 2025-01-11 19:13:00
#
#         เวลาการชำระสินค้า ช่องทางการชำระเงิน ช่องทางการชำระเงิน_(รายละเอียด)  \
# 16305 2025-01-11 19:43:00    เก็บเงินปลายทาง                             NaN
#
#          แผนการผ่อนชำระ ค่าธรรมเนียม_(%)  \
# 16305  Cash on Delivery            3.21%
#
#                                        ตัวเลือกการจัดส่ง *หมายเลขติดตามพัสดุ  \
# 16305  Standard Delivery - ส่งธรรมดาในประเทศ-SPX Express     TH254383577681Q
#
#        ...        จังหวัด      เขต/อำเภอ เวลาที่ทำการสั่งซื้อสำเร็จ  \
# 16305  ...  จังหวัดพัทลุง  อำเภอปากพะยูน        2025-02-07 08:25:00
#
#       Mecanic_cam group  ยอดขายรวม  ส่วนลดรวม  ราคาลูกค้าจ่าย  Disรวม%  \
# 16305      Normal   old        118          0             118      0.0
#
#               duration
# 16305 26 days 13:12:00
#
# [1 rows x 40 columns]

# %%
specific_order.loc[:, 'Year'] = specific_order['วันที่ทำการสั่งซื้อ'].dt.year
specific_order[['Year','ตัวเลือกการจัดส่ง']]
# Out:
# /tmp/ipykernel_3675/3772539632.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   specific_order.loc[:, 'Year'] = specific_order['วันที่ทำการสั่งซื้อ'].dt.year
#        Year                                  ตัวเลือกการจัดส่ง
# 16305  2025  Standard Delivery - ส่งธรรมดาในประเทศ-SPX Express

# %%
unique_orders['duration'].min()
# Out:
# Timedelta('0 days 00:00:00')

# %%
unique_orders.groupby('ช่องทางการชำระเงิน')['duration'].min()
# Out:
# ช่องทางการชำระเงิน
# Google Pay                   0 days 00:01:00
# Mobile Banking               0 days 00:00:00
# QR พร้อมเพย์                 0 days 00:00:00
# SPayLater                    0 days 00:00:00
# ShopeePay - ตัดบัญชีธนาคาร   0 days 00:00:00
# คะแนนบัตรเครดิต              0 days 00:00:00
# บัตรเครดิต/บัตรเดบิต         0 days 00:00:00
# ยอดเงิน ShopeePay            0 days 00:00:00
# เก็บเงินปลายทาง              0 days 01:23:00
# ไม่ต้องชำระเงิน              0 days 00:00:00
# Name: duration, dtype: timedelta64[ns]

# %%
unique_orders.groupby('ช่องทางการชำระเงิน')['duration'].max()
# Out:
# ช่องทางการชำระเงิน
# Google Pay                    0 days 00:01:00
# Mobile Banking                0 days 23:59:00
# QR พร้อมเพย์                  1 days 00:00:00
# SPayLater                     0 days 23:54:00
# ShopeePay - ตัดบัญชีธนาคาร    0 days 23:59:00
# คะแนนบัตรเครดิต               0 days 00:00:00
# บัตรเครดิต/บัตรเดบิต          0 days 23:48:00
# ยอดเงิน ShopeePay             0 days 23:34:00
# เก็บเงินปลายทาง              26 days 13:12:00
# ไม่ต้องชำระเงิน               0 days 00:00:00
# Name: duration, dtype: timedelta64[ns]

# %%
unique_orders.groupby('ช่องทางการชำระเงิน')['duration'].mean()
# Out:
# ช่องทางการชำระเงิน
# Google Pay                             0 days 00:01:00
# Mobile Banking               0 days 00:19:45.466321243
# QR พร้อมเพย์                 0 days 01:08:13.609576427
# SPayLater                    0 days 00:10:10.039194485
# ShopeePay - ตัดบัญชีธนาคาร   0 days 00:16:26.144376049
# คะแนนบัตรเครดิต                        0 days 00:00:00
# บัตรเครดิต/บัตรเดบิต         0 days 00:15:45.092150170
# ยอดเงิน ShopeePay            0 days 00:14:45.047923322
# เก็บเงินปลายทาง              9 days 07:59:17.174455166
# ไม่ต้องชำระเงิน                        0 days 00:00:00
# Name: duration, dtype: timedelta64[ns]

# %%
merged_df = unique_orders.groupby('ช่องทางการชำระเงิน')['duration'].mean()

# %% [markdown]
# #### Distribution of 'Duration' for 'การเก็บเงินปลายทาง' Orders

# %%
cod_orders = unique_orders[unique_orders['ช่องทางการชำระเงิน'] == 'เก็บเงินปลายทาง'].copy()
cod_orders['duration_hours'] = cod_orders['duration'].dt.total_seconds() / 3600

plt.figure(figsize=(10, 6))
sns.histplot(cod_orders['duration_hours'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Duration for \'Kebngernplaitarng\' Orders (Hours)')
plt.xlabel('Duration (Hours)')
plt.ylabel('Number of Orders')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# drop เก็บเงินปลายทางออกเพราะจะระบุใน Paid time เมื่อลูกค้าได้รับของ=จัดส่งสำเร็จ

# %%
# To remove rows with a specific value, we filter the DataFrame
hh = unique_orders[unique_orders['ช่องทางการชำระเงิน'] != 'เก็บเงินปลายทาง']

# Display the result
hh['ช่องทางการชำระเงิน'].unique()
# Out:
# array(['Mobile Banking', 'บัตรเครดิต/บัตรเดบิต', 'SPayLater',
#        'QR พร้อมเพย์', 'ShopeePay - ตัดบัญชีธนาคาร', 'ยอดเงิน ShopeePay',
#        'Google Pay', 'คะแนนบัตรเครดิต', 'ไม่ต้องชำระเงิน'], dtype=object)

# %%
hh['duration'].value_counts()
# Out:
# duration
# 0 days 00:00:00    32783
# 0 days 00:01:00    14346
# 0 days 00:02:00     1296
# 0 days 00:30:00      547
# 0 days 00:03:00      462
#                    ...
# 0 days 16:14:00        1
# 0 days 17:12:00        1
# 0 days 15:57:00        1
# 0 days 02:20:00        1
# 0 days 14:20:00        1
# Name: count, Length: 1025, dtype: int64

# %% [markdown]
# #### กรณี mean

# %%
hh['duration'].mean()
# Out:
# Timedelta('0 days 00:26:48.282999660')

# %% [markdown]
# เมื่อ drop เก็บเงินปลายทางออกแล้วจะเห็นว่า Gap เฉลี่ยจะอยู่ที่ 7.50 วิ ประมาณ 8 นาที ซึ่งตรงนี้น่าสนใจลูกค้าอาจจะกำลังตัดสินใจหรือเปรียบเทียบราคาอยู่

# %%
# hh['Duration_minutes'] = hh['Duration'].dt.total_seconds() / 60

# # Define the range for 'around 7 minutes'
# lower_bound = 6.5
# upper_bound = 7.5

# orders_around_7_minutes = hh[(hh['Duration_minutes'] >= lower_bound) & (hh['Duration_minutes'] <= upper_bound)]

# num_orders = orders_around_7_minutes['Order ID'].nunique()

# print(f"Number of unique orders in 'hh' with a duration around 7 minutes (between {lower_bound} and {upper_bound} minutes): {num_orders}")

# %%
hh_with_duration_flag = hh.copy()
hh_with_duration_flag['duration_minutes'] = hh_with_duration_flag['duration'].dt.total_seconds() / 60

# Define the range for 'around 7 minutes'
lower_bound = 6.5
upper_bound = 7.5

# Now you can modify hh_with_duration_flag freely without warnings
hh_with_duration_flag['is_7_min'] = (hh_with_duration_flag['duration_minutes'] >= lower_bound) & (hh_with_duration_flag['duration_minutes'] <= upper_bound)
num_orders_7_min = hh_with_duration_flag[hh_with_duration_flag['is_7_min']]['หมายเลขคำสั่งซื้อ'].nunique()
print(f"Number of unique orders in 'hh' with a duration around 7 minutes (between {lower_bound} and {upper_bound} minutes): {num_orders_7_min}")
# Out:
# Number of unique orders in 'hh' with a duration around 7 minutes (between 6.5 and 7.5 minutes): 68

# %% [markdown]
# orderID ที่มี Duration อยู่ที่ 6.5-7.5 นาทีมีทั้งหมด 68 orders

# %%
orders_around_7_minutes = hh_with_duration_flag[hh_with_duration_flag['is_7_min']]
product_name_counts = orders_around_7_minutes['ชื่อสินค้า'].value_counts()
display(product_name_counts)
# Out:
# ชื่อสินค้า
# แป้งเจ้านาง 10ก. (แพคเกจใหม่) - Chaonang Perfect Bright UV 2-way Powder Foundation 10g.                                     16
# รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 15g.                                                  12
# รองพื้นเจ้านาง แบบซอง (5ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 5g.                                              6
# แป้งพัฟเจ้านาง To go ขนาด 5g. - Chaonang Perfect Bright UV 2 Way Powder Foundation To go                                     5
# แป้งเจ้านาง (แพคเกจใหม่) - Chaonang Perfect Bright UV 2-way Powder Foundation                                                4
# (สูตรใหม่) รองพื้นเจ้านางผิวกระจก แบบซอง (5ก.) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. ( เครื่องสำอาง ผู้หญิง )     4
# [หมดอายุ 12/2026] คุชชั่นเจ้านาง - Chaonang Glowy Cushion SPF30 PA+++ 15g.                                                   3
# ...

# %% [markdown]
# #### กรณี Max

# %%
hh['duration'].max()
# Out:
# Timedelta('1 days 00:00:00')

# %%
hh_with_duration_flag = hh.copy()
hh_with_duration_flag['duration_minutes'] = hh_with_duration_flag['duration'].dt.total_seconds() / 60
lower_boundm = 23.50
upper_boundm = 24.00
# Now you can modify hh_with_duration_flag freely without warnings
hh_with_duration_flag['is_24_h'] = (hh_with_duration_flag['duration_minutes'] >= 23.50) & (hh_with_duration_flag['duration_minutes'] <= 24.00)
num_orders_7_min = hh_with_duration_flag[hh_with_duration_flag['is_24_h']]['หมายเลขคำสั่งซื้อ'].nunique()
print(f"Number of unique orders in 'hh' with a duration around 7 minutes (between {lower_boundm} and {upper_boundm} minutes): {num_orders_7_min}")
# Out:
# Number of unique orders in 'hh' with a duration around 7 minutes (between 23.5 and 24.0 minutes): 8

# %%
orders_around_24_h = hh_with_duration_flag[hh_with_duration_flag['is_24_h']]
product_name_counts_max = orders_around_24_h['ชื่อสินค้า'].value_counts()
display(product_name_counts_max)
# Out:
# ชื่อสินค้า
# รองพื้นเจ้านาง แบบซอง (5ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 5g.                                             2
# (สูตรใหม่) รองพื้นเจ้านางผิวกระจก แบบซอง (5ก.) - Chaonang Glass Skin Foundation SPF30 PA+++ 5g. ( เครื่องสำอาง ผู้หญิง )    2
# รองพื้นเจ้านาง (15ก.) - Chaonang Radiance Skin Foundation SPF30 PA+++ 15g.                                                  2
# ลิปจุ่มเจ้านาง (3ก.) - Chaonang Liquid Lip Chaonang Ultimate Velvet Lip 3g. exp.22/5/2025                                   1
# แป้งเจ้านาง 10ก. (แพคเกจใหม่) - Chaonang Perfect Bright UV 2-way Powder Foundation 10g.                                     1
# Name: count, dtype: int64

# %% [markdown]
# #### Duration ตาม Mechanic campaign

# %% [markdown]
# อยากทราบว่าแคมเปญมีผลต่อการรีบจ่ายมั้ย

# %%
hh.groupby('Mecanic_cam')['duration'].mean()
# Out:
# Mecanic_cam
# Double Day   0 days 00:35:15.172413793
# Flash Sale   0 days 00:26:43.783783783
# Hello 2025   0 days 00:01:38.823529411
# Mid Month              0 days 01:19:30
# Normal       0 days 00:26:48.504276767
# Pay Day         0 days 00:22:52.500000
# Name: duration, dtype: timedelta64[ns]

# %%
hh.groupby('Mecanic_cam')['duration'].mean()
# Out:
# Mecanic_cam
# Double Day   0 days 00:35:15.172413793
# Flash Sale   0 days 00:26:43.783783783
# Hello 2025   0 days 00:01:38.823529411
# Mid Month              0 days 01:19:30
# Normal       0 days 00:26:48.504276767
# Pay Day         0 days 00:22:52.500000
# Name: duration, dtype: timedelta64[ns]

# %%
merged_df1['หมายเลขคำสั่งซื้อ']
# Out:
# 0        240103UWX9N588
# 1        240103UWX9N588
# 2        240103THAPRG1G
# 3        240103THAPRG1G
# 4        240102SRPHXTVH
#               ...
# 95475    260331JHGT5Q6J
# 95476    260401KMUCRTYX
# 95477    260401KMUCRTYX
# 95478    260331JQFA1UTK
# 95479    260331KGWSY0SN
# Name: หมายเลขคำสั่งซื้อ, Length: 95480, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Prepare data from the 'hh' dataframe (excluding COD)
hh_log = hh.copy()
# Convert duration to minutes for a granular numeric scale
hh_log['Duration_minutes'] = hh_log['duration'].dt.total_seconds() / 60

# Ensure we don't have zeros for log scale (add a very small epsilon if necessary, though Durations > 0 are expected)
hh_log = hh_log[hh_log['Duration_minutes'] > 0]

plt.figure(figsize=(14, 8))
sns.boxplot(x='Mecanic_cam', y='Duration_minutes', data=hh_log, palette='viridis', hue='Mecanic_cam', legend=False)

# Set Y-axis to log scale
plt.yscale('log')

plt.title('Log-Scale Distribution of Transaction Durations by Campaign (Excluding COD)', fontsize=14)
plt.xlabel('Marketing Campaign', fontsize=12)
plt.ylabel('Duration (Minutes) - Log Scale', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', which='both', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
hh['duration'].max()
# Out:
# Timedelta('1 days 00:00:00')

# %%
hh['duration']
# Out:
# 0       0 days 00:00:00
# 2       0 days 00:00:00
# 6       0 days 00:00:00
# 7       0 days 00:00:00
# 9       0 days 05:38:00
#               ...
# 95473   0 days 13:03:00
# 95475   0 days 00:00:00
# 95476   0 days 00:01:00
# 95478   0 days 00:00:00
# 95479   0 days 00:30:00
# Name: duration, Length: 53046, dtype: timedelta64[ns]

# %%
output_path_hh = '/content/drive/MyDrive/intern CHN/hh_data.xlsx'
hh.to_excel(output_path_hh, index=False)
print(f"DataFrame 'hh' ถูกส่งออกไปยัง '{output_path_hh}' เรียบร้อยแล้ว")
# Out:
# DataFrame 'hh' ถูกส่งออกไปยัง '/content/drive/MyDrive/intern CHN/hh_data.xlsx' เรียบร้อยแล้ว

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure unique_orders is correctly defined from the merged_df1
unique_orders1 = merged_df1.drop_duplicates(subset=['หมายเลขคำสั่งซื้อ']).copy()

# Ensure 'วันที่ทำการสั่งซื้อ' and 'เวลาการชำระสินค้า' are datetime objects
unique_orders['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(unique_orders['วันที่ทำการสั่งซื้อ'], errors='coerce')
unique_orders['เวลาการชำระสินค้า'] = pd.to_datetime(unique_orders['เวลาการชำระสินค้า'], errors='coerce')
unique_orders['เวลาที่ทำการสั่งซื้อสำเร็จ'] = pd.to_datetime(unique_orders['เวลาที่ทำการสั่งซื้อสำเร็จ'], errors='coerce')

# Recalculate duration based on payment method logic
cod_mask = unique_orders['ช่องทางการชำระเงิน'] == 'เก็บเงินปลายทาง'
unique_orders.loc[cod_mask, 'duration'] = unique_orders.loc[cod_mask, 'เวลาที่ทำการสั่งซื้อสำเร็จ'] - unique_orders.loc[cod_mask, 'วันที่ทำการสั่งซื้อ']

other_mask = unique_orders['ช่องทางการชำระเงิน'] != 'เก็บเงินปลายทาง'
unique_orders.loc[other_mask, 'duration'] = unique_orders.loc[other_mask, 'เวลาการชำระสินค้า'] - unique_orders.loc[other_mask, 'วันที่ทำการสั่งซื้อ']

# Calculate summary statistics
summary = (
    unique_orders.groupby('ช่องทางการชำระเงิน')['duration']
    .agg(['mean', 'max', 'min'])
    .reset_index()
)

# Convert timedelta to string format for display (e.g., 'HH:MM:SS')
for col in ['mean', 'max', 'min']:
    summary[col] = summary[col].astype(str)

summary.columns = ['Payment Method', 'Mean Duration', 'Max Duration', 'Min Duration']

# Create the table using Matplotlib
fig, ax = plt.subplots(figsize=(12, 8))
ax.axis('off')

table = ax.table(
    cellText=summary.values,
    colLabels=summary.columns,
    loc='center'
)

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)

ax.set_title('Duration Statistics by Payment Method', fontsize=14, pad=20)

plt.tight_layout()
plt.show()

print("Summary of Duration by Payment Method:")
print(summary.to_string())
# Out:
# Summary of Duration by Payment Method:
#                Payment Method              Mean Duration      Max Duration     Min Duration
# 0                  Google Pay            0 days 00:01:00   0 days 00:01:00  0 days 00:01:00
# 1              Mobile Banking  0 days 00:19:45.466321243   0 days 23:59:00  0 days 00:00:00
# 2                QR พร้อมเพย์  0 days 01:08:13.609576427   1 days 00:00:00  0 days 00:00:00
# 3                   SPayLater  0 days 00:10:10.039194485   0 days 23:54:00  0 days 00:00:00
# 4  ShopeePay - ตัดบัญชีธนาคาร  0 days 00:16:26.144376049   0 days 23:59:00  0 days 00:00:00
# 5             คะแนนบัตรเครดิต            0 days 00:00:00   0 days 00:00:00  0 days 00:00:00
# 6        บัตรเครดิต/บัตรเดบิต  0 days 00:15:45.092150170   0 days 23:48:00  0 days 00:00:00
# 7           ยอดเงิน ShopeePay  0 days 00:14:45.047923322   0 days 23:34:00  0 days 00:00:00
# 8             เก็บเงินปลายทาง  9 days 07:59:17.174455166  26 days 13:12:00  0 days 01:23:00
# ...

# %%
unique_orders['ช่องทางการชำระเงิน'].unique()
# Out:
# array(['Mobile Banking', 'บัตรเครดิต/บัตรเดบิต', 'เก็บเงินปลายทาง',
#        'SPayLater', 'QR พร้อมเพย์', 'ShopeePay - ตัดบัญชีธนาคาร',
#        'ยอดเงิน ShopeePay', 'Google Pay', 'คะแนนบัตรเครดิต',
#        'ไม่ต้องชำระเงิน'], dtype=object)

# %% [markdown]
# # ติดตั้งภาษาไทย

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import os

# Update package lists and install thai-fonts
# !apt-get update -qq
# !apt-get install -y fonts-thai-tlwg -qq

# Clear matplotlib's font cache
# The correct way to clear the cache is often to delete the cache file or rebuild via system calls.
# For Colab, often re-running the cell or relying on findSystemFonts/addfont is sufficient.
# fm.fontManager.clear() # Removed as it causes AttributeError

# Find a Thai font that was just installed
# Common Thai fonts are 'Sarabun' or 'TH Sarabun New' or those from tlwg.
# Searching through common font directories
font_dirs = ['/usr/share/fonts/truetype/thai/', '/usr/share/fonts/truetype/liberation/', '/usr/share/fonts/truetype/THSarabunNew/', '/usr/share/fonts/truetype/tlwg/'] # Added common path for tlwg fonts
font_files = fm.findSystemFonts(fontpaths=font_dirs)

thai_font_path = None
# Prioritize TH Sarabun New or other Sarabun fonts if available
for font_file in font_files:
    if 'THSarabunNew.ttf' in font_file or 'Sarabun' in font_file or 'Laksaman.ttf' in font_file: # Added Laksaman as a common tlwg font
        thai_font_path = font_file
        break

if thai_font_path:
    print(f"Found Thai font: {thai_font_path}")
    # Add font to matplotlib font manager (though findSystemFonts already registers them)
    fm.fontManager.addfont(thai_font_path)

    # Set default font to the Thai font
    plt.rcParams['font.family'] = fm.FontProperties(fname=thai_font_path).get_name()
    plt.rcParams['axes.unicode_minus'] = False # Ensure minus signs are displayed correctly
    print(f"Matplotlib default font set to: {plt.rcParams['font.family']}")
else:
    print("Warning: No suitable Thai font found. Plot text might not display correctly.")
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package fonts-tlwg-garuda-ttf.
# (Reading database ... 118242 files and directories currently installed.)
# Preparing to unpack .../00-fonts-tlwg-garuda-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-garuda-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-garuda.
# Preparing to unpack .../01-fonts-tlwg-garuda_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-garuda (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-kinnari-ttf.
# Preparing to unpack .../02-fonts-tlwg-kinnari-ttf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-kinnari-ttf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-kinnari.
# Preparing to unpack .../03-fonts-tlwg-kinnari_1%3a0.7.3-1_all.deb ...
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,6))
ax.axis('off')

table = ax.table(
    cellText=summary.values,
    colLabels=summary.columns,
    loc='center'
)

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)

plt.show()

# %%
import matplotlib.pyplot as plt

labels = [
    'คอนเฟิร์มออเดอร์และรอทัน',
    'แจ้ง'
]

counts = [16, 4]

plt.figure(figsize=(8,5))

bars = plt.bar(
    labels,
    counts
)

plt.title('Gap เฉลี่ยของ Prompt Pay 20 นาที 52 วินาที +-5 นาที')
plt.ylabel('จำนวน(ชิ้น)')

for bar in bars:
    height = bar.get_height()

    plt.text(
        bar.get_x()+bar.get_width()/2,
        height+0.2,
        str(int(height)),
        ha='center'
    )

plt.show()
